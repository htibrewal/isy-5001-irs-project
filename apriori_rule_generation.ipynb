# %%
import numpy as np
import pandas as pd
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# %%
DATASET_PATH = "./cleaned_datasets/enlarged_dataset.csv"
data = pd.read_csv(DATASET_PATH)
data.head()
# Out:
#    PO_NUM         ITEM_NAME                       PART_DESCRIPTION ITEM_CODE  \
# 0  100000           Gripper     Pneumatic gripper for robotic arms   MOT7793
# 1  100000        3D Printer     Compact 3D printer for prototyping   MOT1546
# 2  100001   Pressure Sensor         High-precision pressure sensor   KYO7240
# 3  100001  Proximity Sensor             Inductive proximity sensor   KYO2884
# 4  100002   Control Cabinet  Industrial control cabinet with locks   IND4956
#
#                          SUPPLIER_NAME SUPPLIER_CODE  ORDERED_QUANTITY  \
# 0  MOTHERSON SUMI WIRING INDIA LIMITED      VD904014                39
# 1  MOTHERSON SUMI WIRING INDIA LIMITED      VD904014               180
# 2         KYOWA MANUFACTURING CO., LTD      VD650721                67
# 3         KYOWA MANUFACTURING CO., LTD      VD650721               179
# 4                  INDEANA ENGINEERING      VD671527               300
#
#    FAULTED_PARTS    PRICE   PO_VALUE DOWNPAYMENT_DATE DELIVERY_DATE
# 0              0  3740.04  145861.56       2023-09-05    2023-09-26
# 1              9  2547.14  458485.20       2023-10-22    2023-11-29
# 2              0   220.82   14794.94       2023-09-30    2023-11-06
# 3              0  4716.11  844183.69       2023-12-03    2023-12-30
# 4             15  1526.58  457974.00       2023-09-02    2023-12-10

# %%
# randomly sample 50% of PO_NUMB and keep records for those
unique_pos = data['PO_NUM'].unique()
po_subset = np.random.choice(unique_pos, size=len(unique_pos)//5, replace = False)
print("data size : ", data.shape)
data_subset = data[data['PO_NUM'].isin(po_subset)]
print("data_susbset size : ", data_subset.shape)
# Out:
# data size :  (58667, 12)
# data_susbset size :  (11651, 12)

# %%
baskets = data.groupby('PO_NUM')['ITEM_NAME'].apply(list).tolist()
# baskets = [ basket if len(basket) > 1 else None for basket in baskets ]
# remove_none = [ basket for basket in baskets if basket is not None ]
# baskets = remove_none
baskets
# Out:
# [['Gripper', '3D Printer'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Control Cabinet'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Power Supply'],
#  ['Proximity Sensor', 'Control Cabinet', 'PLC Controller'],
#  ['VFD Drive'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Resistor', 'Power Supply'],
#  ['Temperature Sensor', 'PLC Controller'],
#  ['Temperature Sensor', 'Pressure Sensor', 'VFD Drive'],
#  ['Resistor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Proximity Sensor'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['12V DC Motor', 'Temperature Sensor'],
#  ['Proximity Sensor'],
#  ['Servo Motor Driver', 'Control Cabinet'],
#  ['Servo Motor Driver'],
#  ['VFD Drive'],
#  ['Servo Motor Driver',
#   'Stepper Motor',
#   'Proximity Sensor',
#   'Pressure Sensor'],
#  ['12V DC Motor', 'Control Cabinet', 'VFD Drive'],
#  ['12V DC Motor'],
#  ['Servo Motor Driver', 'Pressure Sensor'],
#  ['Proximity Sensor', 'PLC Controller'],
#  ['10A Relay Switch'],
#  ['Control Cabinet'],
#  ['Temperature Sensor'],
#  ['10A Relay Switch', '3D Printer'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Power Supply'],
#  ['Resistor', '10A Relay Switch', 'Gripper', 'Robotic Arm'],
#  ['Power Supply'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Control Cabinet'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor'],
#  ['Gripper', 'Robotic Arm'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver',
#   '12V DC Motor',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['10A Relay Switch', 'Robotic Arm'],
#  ['3D Printer'],
#  ['12V DC Motor', 'VFD Drive'],
#  ['Stepper Motor', 'Control Cabinet'],
#  ['Resistor', '10A Relay Switch'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Proximity Sensor'],
#  ['VFD Drive'],
#  ['Pressure Sensor'],
#  ['Servo Motor Driver', 'VFD Drive', 'Control Cabinet'],
#  ['Resistor'],
#  ['Temperature Sensor',
#   'Pressure Sensor',
#   'PLC Controller',
#   'Control Cabinet'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Power Supply'],
#  ['Stepper Motor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Stepper Motor', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Pressure Sensor', 'Temperature Sensor', 'PLC Controller'],
#  ['Resistor', 'Gripper', '3D Printer'],
#  ['Stepper Motor'],
#  ['Pressure Sensor'],
#  ['Pressure Sensor'],
#  ['12V DC Motor', 'Stepper Motor', 'Temperature Sensor', 'Proximity Sensor'],
#  ['Resistor', 'Power Supply', 'Robotic Arm'],
#  ['Proximity Sensor', 'Temperature Sensor', 'PLC Controller'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['10A Relay Switch'],
#  ['Pressure Sensor'],
#  ['Gripper', '3D Printer'],
#  ['Temperature Sensor'],
#  ['Resistor'],
#  ['Gripper'],
#  ['Temperature Sensor', 'VFD Drive', 'Control Cabinet'],
#  ['Power Supply'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Resistor'],
#  ['10A Relay Switch'],
#  ['Power Supply', '10A Relay Switch', '3D Printer'],
#  ['Stepper Motor', '12V DC Motor', 'Control Cabinet'],
#  ['Stepper Motor'],
#  ['12V DC Motor', 'Control Cabinet'],
#  ['Servo Motor Driver', 'Pressure Sensor', 'Temperature Sensor'],
#  ['Resistor'],
#  ['VFD Drive', 'PLC Controller'],
#  ['12V DC Motor', 'Stepper Motor', 'Control Cabinet', 'VFD Drive'],
#  ['Servo Motor Driver', 'Temperature Sensor'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Temperature Sensor'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['12V DC Motor'],
#  ['PLC Controller', 'VFD Drive'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Robotic Arm'],
#  ['Stepper Motor', 'Proximity Sensor', 'Pressure Sensor'],
#  ['Pressure Sensor'],
#  ['Temperature Sensor', 'Control Cabinet'],
#  ['10A Relay Switch'],
#  ['PLC Controller'],
#  ['10A Relay Switch', 'Resistor'],
#  ['10A Relay Switch', 'Gripper'],
#  ['Power Supply', 'Resistor', '3D Printer'],
#  ['Robotic Arm'],
#  ['12V DC Motor', 'Stepper Motor', 'PLC Controller', 'VFD Drive'],
#  ['Servo Motor Driver', 'Control Cabinet'],
#  ['Stepper Motor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Pressure Sensor'],
#  ['Servo Motor Driver'],
#  ['Robotic Arm', '3D Printer'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Stepper Motor'],
#  ['Control Cabinet'],
#  ['Power Supply', 'Resistor', 'Gripper'],
#  ['10A Relay Switch'],
#  ['3D Printer', 'Gripper'],
#  ['Resistor', 'Power Supply', 'Robotic Arm', 'Gripper'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Temperature Sensor', 'PLC Controller'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Power Supply', 'Resistor', '3D Printer'],
#  ['10A Relay Switch', 'Resistor'],
#  ['10A Relay Switch', 'Resistor', 'Gripper', 'Robotic Arm'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Stepper Motor', 'VFD Drive'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['10A Relay Switch'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Resistor', '3D Printer', 'Gripper'],
#  ['Temperature Sensor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['PLC Controller'],
#  ['Robotic Arm', 'Gripper'],
#  ['Stepper Motor', '12V DC Motor', 'Temperature Sensor', 'Proximity Sensor'],
#  ['10A Relay Switch', '3D Printer', 'Robotic Arm'],
#  ['Stepper Motor', 'Servo Motor Driver', 'PLC Controller', 'VFD Drive'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Resistor', 'Robotic Arm'],
#  ['Stepper Motor'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['Power Supply', 'Resistor'],
#  ['Power Supply'],
#  ['Robotic Arm'],
#  ['Resistor', '3D Printer'],
#  ['Gripper', '3D Printer'],
#  ['Power Supply', '10A Relay Switch'],
#  ['Pressure Sensor', 'PLC Controller'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['PLC Controller'],
#  ['Pressure Sensor'],
#  ['Power Supply', 'Gripper'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Pressure Sensor'],
#  ['10A Relay Switch', '3D Printer', 'Robotic Arm'],
#  ['Control Cabinet'],
#  ['Pressure Sensor', 'Temperature Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['Stepper Motor'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['3D Printer'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Gripper'],
#  ['3D Printer'],
#  ['10A Relay Switch'],
#  ['Servo Motor Driver'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['Stepper Motor', 'Servo Motor Driver', 'Pressure Sensor'],
#  ['Proximity Sensor'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Pressure Sensor', 'PLC Controller'],
#  ['Pressure Sensor'],
#  ['Power Supply', '3D Printer', 'Gripper'],
#  ['Power Supply', 'Resistor', '3D Printer'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Power Supply', '10A Relay Switch', 'Robotic Arm'],
#  ['Proximity Sensor'],
#  ['Servo Motor Driver', 'Temperature Sensor', 'Proximity Sensor'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Power Supply', 'Resistor'],
#  ['Servo Motor Driver', '12V DC Motor', 'Pressure Sensor', 'Proximity Sensor'],
#  ['PLC Controller'],
#  ['Servo Motor Driver'],
#  ['Servo Motor Driver', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Stepper Motor', 'Pressure Sensor', 'Temperature Sensor'],
#  ['Stepper Motor', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Temperature Sensor'],
#  ['3D Printer', 'Gripper'],
#  ['Robotic Arm', '3D Printer'],
#  ['VFD Drive'],
#  ['Power Supply'],
#  ['Proximity Sensor', 'Pressure Sensor', 'PLC Controller'],
#  ['Resistor'],
#  ['Gripper'],
#  ['Pressure Sensor'],
#  ['Proximity Sensor'],
#  ['10A Relay Switch', 'Gripper'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Proximity Sensor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Power Supply', 'Resistor', 'Robotic Arm', 'Gripper'],
#  ['Stepper Motor', '12V DC Motor', 'Temperature Sensor'],
#  ['Resistor', '10A Relay Switch'],
#  ['Power Supply', 'Resistor'],
#  ['Temperature Sensor'],
#  ['Servo Motor Driver', 'Control Cabinet'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'VFD Drive', 'PLC Controller'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Resistor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Proximity Sensor'],
#  ['Servo Motor Driver'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Resistor', 'Robotic Arm'],
#  ['Pressure Sensor', 'VFD Drive'],
#  ['Temperature Sensor'],
#  ['10A Relay Switch'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Temperature Sensor'],
#  ['Stepper Motor'],
#  ['Servo Motor Driver', 'Pressure Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Resistor', 'Power Supply'],
#  ['PLC Controller'],
#  ['Power Supply', 'Resistor'],
#  ['12V DC Motor'],
#  ['Gripper', '3D Printer'],
#  ['Servo Motor Driver', 'Control Cabinet', 'PLC Controller'],
#  ['Temperature Sensor'],
#  ['Power Supply'],
#  ['Stepper Motor', 'Servo Motor Driver', 'PLC Controller', 'Control Cabinet'],
#  ['10A Relay Switch'],
#  ['Power Supply'],
#  ['Servo Motor Driver', 'Control Cabinet', 'VFD Drive'],
#  ['Robotic Arm', 'Gripper'],
#  ['Servo Motor Driver',
#   'Stepper Motor',
#   'Proximity Sensor',
#   'Temperature Sensor'],
#  ['Proximity Sensor', 'Pressure Sensor', 'PLC Controller'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Power Supply', '3D Printer', 'Gripper'],
#  ['Gripper', 'Robotic Arm'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Temperature Sensor', 'Pressure Sensor', 'VFD Drive'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Servo Motor Driver', '12V DC Motor', 'Temperature Sensor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Stepper Motor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Proximity Sensor', 'Temperature Sensor', 'PLC Controller'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Robotic Arm'],
#  ['Resistor', 'Power Supply', '3D Printer'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Control Cabinet'],
#  ['Power Supply', 'Resistor'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Servo Motor Driver', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor', 'Pressure Sensor'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Stepper Motor', 'Proximity Sensor', 'Pressure Sensor'],
#  ['Robotic Arm'],
#  ['Power Supply', 'Robotic Arm'],
#  ['Power Supply', '10A Relay Switch', 'Gripper'],
#  ['Pressure Sensor', 'Temperature Sensor', 'VFD Drive'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Servo Motor Driver', 'Pressure Sensor', 'Temperature Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Robotic Arm', '3D Printer'],
#  ['Resistor', 'Power Supply'],
#  ['3D Printer'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Gripper', '3D Printer'],
#  ['Stepper Motor', '12V DC Motor', 'VFD Drive', 'Control Cabinet'],
#  ['Resistor', '10A Relay Switch', '3D Printer'],
#  ['Proximity Sensor'],
#  ['Gripper', '3D Printer'],
#  ['10A Relay Switch', 'Resistor', 'Robotic Arm'],
#  ['3D Printer'],
#  ['Pressure Sensor'],
#  ['Temperature Sensor'],
#  ['Servo Motor Driver'],
#  ['Gripper', '3D Printer'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Proximity Sensor', 'Pressure Sensor', 'VFD Drive'],
#  ['Gripper'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Power Supply', 'Robotic Arm'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'PLC Controller'],
#  ['12V DC Motor', 'Pressure Sensor'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['VFD Drive'],
#  ['10A Relay Switch'],
#  ['Control Cabinet'],
#  ['Servo Motor Driver', 'Temperature Sensor', 'Pressure Sensor'],
#  ['Power Supply'],
#  ['Power Supply', 'Resistor'],
#  ['12V DC Motor'],
#  ['Power Supply', 'Gripper', 'Robotic Arm'],
#  ['Pressure Sensor', 'Proximity Sensor', 'PLC Controller', 'VFD Drive'],
#  ['Pressure Sensor', 'Temperature Sensor', 'VFD Drive', 'PLC Controller'],
#  ['Robotic Arm', '3D Printer'],
#  ['Resistor'],
#  ['PLC Controller'],
#  ['Pressure Sensor'],
#  ['Resistor'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['10A Relay Switch'],
#  ['Temperature Sensor',
#   'Pressure Sensor',
#   'PLC Controller',
#   'Control Cabinet'],
#  ['Power Supply', 'Resistor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['12V DC Motor', 'Stepper Motor', 'Control Cabinet'],
#  ['3D Printer'],
#  ['Control Cabinet'],
#  ['Power Supply', '3D Printer'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Pressure Sensor', 'PLC Controller'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Resistor'],
#  ['Resistor'],
#  ['Power Supply', 'Resistor'],
#  ['Gripper'],
#  ['Resistor', '10A Relay Switch'],
#  ['Gripper'],
#  ['Gripper'],
#  ['Pressure Sensor'],
#  ['Resistor'],
#  ['Control Cabinet'],
#  ['PLC Controller'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['Gripper', '3D Printer'],
#  ['Stepper Motor', 'Pressure Sensor', 'Proximity Sensor'],
#  ['10A Relay Switch'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Temperature Sensor'],
#  ['12V DC Motor', 'Proximity Sensor'],
#  ['Temperature Sensor', 'VFD Drive'],
#  ['Temperature Sensor'],
#  ['Power Supply', 'Resistor'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor', 'Control Cabinet', 'VFD Drive'],
#  ['PLC Controller', 'VFD Drive'],
#  ['12V DC Motor'],
#  ['12V DC Motor', 'Stepper Motor', 'Control Cabinet', 'VFD Drive'],
#  ['Resistor', 'Power Supply', 'Gripper', '3D Printer'],
#  ['Robotic Arm'],
#  ['Resistor', 'Power Supply'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Resistor', 'Power Supply', '3D Printer', 'Gripper'],
#  ['Proximity Sensor'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['12V DC Motor'],
#  ['12V DC Motor'],
#  ['Control Cabinet'],
#  ['10A Relay Switch', 'Gripper', '3D Printer'],
#  ['Pressure Sensor'],
#  ['Power Supply'],
#  ['10A Relay Switch'],
#  ['Resistor', 'Power Supply'],
#  ['Stepper Motor', 'PLC Controller', 'Control Cabinet'],
#  ['Robotic Arm'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['Temperature Sensor'],
#  ['Gripper', 'Robotic Arm'],
#  ['Gripper'],
#  ['10A Relay Switch', '3D Printer'],
#  ['Resistor'],
#  ['Resistor', '10A Relay Switch'],
#  ['Proximity Sensor'],
#  ['Robotic Arm'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['PLC Controller'],
#  ['Robotic Arm', '3D Printer'],
#  ['Resistor', 'Power Supply'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Power Supply', '10A Relay Switch', '3D Printer'],
#  ['Robotic Arm'],
#  ['Robotic Arm', 'Gripper'],
#  ['Power Supply', '10A Relay Switch', 'Gripper', '3D Printer'],
#  ['Stepper Motor', 'Servo Motor Driver', 'VFD Drive', 'PLC Controller'],
#  ['Stepper Motor', 'Proximity Sensor', 'Pressure Sensor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['10A Relay Switch'],
#  ['3D Printer', 'Robotic Arm'],
#  ['10A Relay Switch'],
#  ['12V DC Motor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Robotic Arm'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['10A Relay Switch'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['Stepper Motor', '12V DC Motor', 'VFD Drive'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Pressure Sensor'],
#  ['Pressure Sensor',
#   'Temperature Sensor',
#   'Control Cabinet',
#   'PLC Controller'],
#  ['Control Cabinet'],
#  ['Pressure Sensor', 'Temperature Sensor', 'PLC Controller'],
#  ['Servo Motor Driver', 'Proximity Sensor', 'Pressure Sensor'],
#  ['Power Supply', 'Resistor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Power Supply', 'Resistor'],
#  ['Stepper Motor', 'Servo Motor Driver', 'Temperature Sensor'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Pressure Sensor'],
#  ['Resistor'],
#  ['Power Supply'],
#  ['12V DC Motor', 'Stepper Motor', 'Proximity Sensor'],
#  ['Robotic Arm'],
#  ['Gripper'],
#  ['Stepper Motor'],
#  ['3D Printer'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Resistor', '10A Relay Switch', 'Robotic Arm', '3D Printer'],
#  ['Pressure Sensor'],
#  ['Temperature Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Stepper Motor'],
#  ['Servo Motor Driver', 'Proximity Sensor'],
#  ['Power Supply', '10A Relay Switch'],
#  ['Servo Motor Driver', '12V DC Motor', 'VFD Drive', 'Control Cabinet'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Temperature Sensor', 'Proximity Sensor', 'Control Cabinet'],
#  ['Stepper Motor', '12V DC Motor', 'Proximity Sensor', 'Pressure Sensor'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Stepper Motor'],
#  ['Resistor', '10A Relay Switch'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['3D Printer'],
#  ['3D Printer'],
#  ['Servo Motor Driver', 'Stepper Motor', 'PLC Controller'],
#  ['Temperature Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'PLC Controller', 'VFD Drive'],
#  ['3D Printer', 'Gripper'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Proximity Sensor', 'PLC Controller', 'Control Cabinet'],
#  ['Temperature Sensor', 'Proximity Sensor', 'VFD Drive', 'Control Cabinet'],
#  ['PLC Controller'],
#  ['Resistor', '10A Relay Switch'],
#  ['3D Printer'],
#  ['3D Printer', 'Robotic Arm'],
#  ['12V DC Motor', 'Servo Motor Driver', 'VFD Drive'],
#  ['Stepper Motor', 'Servo Motor Driver', 'VFD Drive', 'PLC Controller'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'PLC Controller', 'VFD Drive'],
#  ['VFD Drive'],
#  ['Servo Motor Driver'],
#  ['10A Relay Switch', 'Robotic Arm', 'Gripper'],
#  ['Resistor', '10A Relay Switch'],
#  ['Servo Motor Driver'],
#  ['10A Relay Switch'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['PLC Controller'],
#  ['Resistor'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['VFD Drive', 'PLC Controller'],
#  ['Robotic Arm', '3D Printer'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['PLC Controller'],
#  ['3D Printer'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['PLC Controller'],
#  ['Power Supply', 'Resistor'],
#  ['Power Supply', '3D Printer', 'Gripper'],
#  ['VFD Drive', 'PLC Controller'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['VFD Drive', 'PLC Controller'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['10A Relay Switch', 'Resistor', 'Gripper'],
#  ['Stepper Motor', '12V DC Motor', 'VFD Drive', 'PLC Controller'],
#  ['Stepper Motor', '12V DC Motor', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Power Supply', '10A Relay Switch'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Resistor', 'Gripper', '3D Printer'],
#  ['3D Printer'],
#  ['12V DC Motor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Power Supply', '10A Relay Switch'],
#  ['10A Relay Switch', '3D Printer'],
#  ['Resistor', 'Robotic Arm', '3D Printer'],
#  ['3D Printer', 'Gripper'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Servo Motor Driver'],
#  ['Resistor', 'Power Supply'],
#  ['Servo Motor Driver', 'Pressure Sensor', 'Temperature Sensor'],
#  ['Stepper Motor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Proximity Sensor'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Robotic Arm'],
#  ['12V DC Motor', 'PLC Controller'],
#  ['Robotic Arm'],
#  ['10A Relay Switch', 'Power Supply', 'Gripper'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Stepper Motor', 'PLC Controller'],
#  ['Power Supply', 'Resistor', 'Gripper'],
#  ['12V DC Motor'],
#  ['Temperature Sensor'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Proximity Sensor'],
#  ['PLC Controller'],
#  ['10A Relay Switch'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['10A Relay Switch', 'Robotic Arm', 'Gripper'],
#  ['Gripper'],
#  ['VFD Drive'],
#  ['Pressure Sensor', 'VFD Drive'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['Resistor'],
#  ['Stepper Motor'],
#  ['Servo Motor Driver'],
#  ['Servo Motor Driver', '12V DC Motor', 'PLC Controller', 'Control Cabinet'],
#  ['Robotic Arm'],
#  ['Pressure Sensor'],
#  ['Gripper', '3D Printer'],
#  ['VFD Drive'],
#  ['Gripper', '3D Printer'],
#  ['10A Relay Switch', '3D Printer'],
#  ['3D Printer'],
#  ['Temperature Sensor', 'VFD Drive'],
#  ['12V DC Motor', 'Stepper Motor', 'VFD Drive', 'PLC Controller'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Control Cabinet'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Servo Motor Driver'],
#  ['Temperature Sensor'],
#  ['Control Cabinet'],
#  ['Power Supply', 'Resistor'],
#  ['Proximity Sensor', 'Pressure Sensor', 'Control Cabinet', 'PLC Controller'],
#  ['Resistor', '10A Relay Switch', 'Robotic Arm', '3D Printer'],
#  ['Proximity Sensor', 'Control Cabinet', 'PLC Controller'],
#  ['12V DC Motor', 'Pressure Sensor', 'Proximity Sensor'],
#  ['10A Relay Switch'],
#  ['Stepper Motor'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['PLC Controller'],
#  ['Gripper', '3D Printer'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['PLC Controller', 'VFD Drive'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Stepper Motor', 'PLC Controller', 'VFD Drive'],
#  ['Pressure Sensor', 'PLC Controller', 'VFD Drive'],
#  ['Robotic Arm'],
#  ['Power Supply'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor', 'Proximity Sensor'],
#  ['Resistor', 'Robotic Arm', 'Gripper'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Servo Motor Driver',
#   'Stepper Motor',
#   'Pressure Sensor',
#   'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Stepper Motor', 'Servo Motor Driver', 'VFD Drive', 'PLC Controller'],
#  ['Temperature Sensor', 'VFD Drive', 'PLC Controller'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Control Cabinet'],
#  ['Stepper Motor', 'Temperature Sensor', 'Proximity Sensor'],
#  ['Temperature Sensor', 'PLC Controller'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Power Supply', '10A Relay Switch', 'Gripper', '3D Printer'],
#  ['Pressure Sensor', 'Proximity Sensor', 'Control Cabinet'],
#  ['Gripper', 'Robotic Arm'],
#  ['3D Printer'],
#  ['Resistor'],
#  ['Resistor', 'Power Supply'],
#  ['3D Printer', 'Gripper'],
#  ['PLC Controller'],
#  ['Control Cabinet'],
#  ['Temperature Sensor', 'Pressure Sensor', 'PLC Controller'],
#  ['Proximity Sensor', 'Control Cabinet', 'PLC Controller'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Robotic Arm', '3D Printer'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Power Supply', 'Robotic Arm', '3D Printer'],
#  ['Robotic Arm'],
#  ['Gripper'],
#  ['VFD Drive'],
#  ['Servo Motor Driver', 'Stepper Motor', 'PLC Controller'],
#  ['Pressure Sensor', 'Proximity Sensor', 'Control Cabinet'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Servo Motor Driver'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Stepper Motor'],
#  ['VFD Drive'],
#  ['10A Relay Switch'],
#  ['Control Cabinet'],
#  ['Pressure Sensor'],
#  ['10A Relay Switch'],
#  ['Power Supply'],
#  ['Resistor', 'Power Supply'],
#  ['12V DC Motor', 'Control Cabinet'],
#  ['Pressure Sensor', 'VFD Drive', 'PLC Controller'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Proximity Sensor'],
#  ['10A Relay Switch', '3D Printer', 'Robotic Arm'],
#  ['Pressure Sensor'],
#  ['Stepper Motor', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'VFD Drive', 'Control Cabinet'],
#  ['Temperature Sensor', 'Proximity Sensor', 'VFD Drive'],
#  ['Resistor'],
#  ['3D Printer'],
#  ['VFD Drive'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Gripper'],
#  ['Proximity Sensor'],
#  ['12V DC Motor', 'Pressure Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Power Supply', 'Resistor', 'Gripper'],
#  ['Servo Motor Driver', 'Temperature Sensor', 'Pressure Sensor'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Robotic Arm', '3D Printer'],
#  ['Stepper Motor'],
#  ['Power Supply'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['12V DC Motor'],
#  ['10A Relay Switch', 'Robotic Arm'],
#  ['VFD Drive'],
#  ['Power Supply'],
#  ['Stepper Motor'],
#  ['Pressure Sensor'],
#  ['Temperature Sensor'],
#  ['10A Relay Switch', 'Resistor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'VFD Drive'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Servo Motor Driver',
#   'Stepper Motor',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['Power Supply'],
#  ['3D Printer', 'Gripper'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['Pressure Sensor', 'PLC Controller', 'VFD Drive'],
#  ['Control Cabinet'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Servo Motor Driver', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Pressure Sensor', 'Temperature Sensor', 'VFD Drive', 'Control Cabinet'],
#  ['Proximity Sensor', 'VFD Drive', 'PLC Controller'],
#  ['Control Cabinet'],
#  ['Temperature Sensor'],
#  ['3D Printer'],
#  ['Resistor', 'Power Supply'],
#  ['Control Cabinet'],
#  ['Resistor', 'Gripper'],
#  ['Resistor', '3D Printer', 'Gripper'],
#  ['Pressure Sensor', 'VFD Drive'],
#  ['Proximity Sensor'],
#  ['Resistor', 'Gripper'],
#  ['Power Supply', 'Resistor', 'Robotic Arm'],
#  ['Pressure Sensor', 'VFD Drive'],
#  ['Robotic Arm'],
#  ['Resistor'],
#  ['Resistor', 'Power Supply'],
#  ['Pressure Sensor'],
#  ['Gripper'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Resistor'],
#  ['VFD Drive'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Control Cabinet'],
#  ['Proximity Sensor', 'Pressure Sensor', 'VFD Drive', 'Control Cabinet'],
#  ['3D Printer', 'Gripper'],
#  ['Power Supply'],
#  ['Control Cabinet', 'PLC Controller'],
#  ['12V DC Motor'],
#  ['PLC Controller'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Power Supply', '10A Relay Switch'],
#  ['Servo Motor Driver', 'Control Cabinet', 'PLC Controller'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Servo Motor Driver'],
#  ['Proximity Sensor'],
#  ['3D Printer', 'Gripper'],
#  ['Resistor'],
#  ['Stepper Motor'],
#  ['Proximity Sensor'],
#  ['Stepper Motor', 'Servo Motor Driver', 'PLC Controller'],
#  ['VFD Drive'],
#  ['Resistor', 'Robotic Arm'],
#  ['10A Relay Switch', 'Robotic Arm'],
#  ['Stepper Motor'],
#  ['Resistor', 'Power Supply'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Servo Motor Driver'],
#  ['PLC Controller'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Resistor', 'Power Supply'],
#  ['VFD Drive', 'PLC Controller'],
#  ['Gripper', '3D Printer'],
#  ['Stepper Motor', 'Servo Motor Driver', 'PLC Controller'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Stepper Motor'],
#  ['Resistor', '3D Printer'],
#  ['Gripper', '3D Printer'],
#  ['Stepper Motor'],
#  ['Resistor', 'Power Supply', '3D Printer'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver', '12V DC Motor', 'Control Cabinet'],
#  ['Proximity Sensor', 'VFD Drive'],
#  ['10A Relay Switch'],
#  ['Power Supply', 'Resistor'],
#  ['12V DC Motor', 'Control Cabinet', 'PLC Controller'],
#  ['Temperature Sensor'],
#  ['12V DC Motor', 'Control Cabinet', 'PLC Controller'],
#  ['Temperature Sensor', 'Proximity Sensor', 'PLC Controller', 'VFD Drive'],
#  ['Temperature Sensor', 'Pressure Sensor', 'Control Cabinet'],
#  ['Robotic Arm'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Servo Motor Driver', 'PLC Controller', 'VFD Drive'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['10A Relay Switch', 'Gripper', '3D Printer'],
#  ['Temperature Sensor', 'Control Cabinet'],
#  ['Servo Motor Driver'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Stepper Motor', 'VFD Drive', 'Control Cabinet'],
#  ['Temperature Sensor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['10A Relay Switch', 'Gripper', '3D Printer'],
#  ['Resistor', 'Power Supply'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['12V DC Motor'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Temperature Sensor'],
#  ['Resistor', '3D Printer'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['12V DC Motor', 'Stepper Motor', 'VFD Drive', 'Control Cabinet'],
#  ['Resistor'],
#  ['Robotic Arm', 'Gripper'],
#  ['VFD Drive'],
#  ['Gripper'],
#  ['3D Printer'],
#  ['Resistor', 'Power Supply', 'Robotic Arm'],
#  ['Power Supply'],
#  ['Power Supply', '10A Relay Switch', 'Gripper'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Proximity Sensor'],
#  ['12V DC Motor'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['12V DC Motor', 'Stepper Motor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Power Supply', '10A Relay Switch', '3D Printer'],
#  ['3D Printer'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Pressure Sensor', 'Temperature Sensor', 'VFD Drive'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Servo Motor Driver',
#   'Stepper Motor',
#   'Temperature Sensor',
#   'Proximity Sensor'],
#  ['10A Relay Switch', '3D Printer'],
#  ['Gripper', 'Robotic Arm'],
#  ['Resistor', 'Power Supply'],
#  ['12V DC Motor', 'Control Cabinet'],
#  ['12V DC Motor', 'Servo Motor Driver', 'VFD Drive'],
#  ['Temperature Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Power Supply', '10A Relay Switch', 'Gripper', '3D Printer'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Stepper Motor', 'Temperature Sensor'],
#  ['3D Printer', 'Gripper'],
#  ['VFD Drive'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Pressure Sensor'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['PLC Controller'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['12V DC Motor', 'Servo Motor Driver', 'PLC Controller', 'Control Cabinet'],
#  ['Proximity Sensor', 'Temperature Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['12V DC Motor', 'Proximity Sensor', 'Pressure Sensor'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Temperature Sensor', 'PLC Controller', 'Control Cabinet'],
#  ['Proximity Sensor'],
#  ['Temperature Sensor'],
#  ['12V DC Motor', 'PLC Controller'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Power Supply'],
#  ['Resistor', 'Power Supply'],
#  ['Gripper', '3D Printer'],
#  ['Temperature Sensor', 'Proximity Sensor', 'PLC Controller'],
#  ['Stepper Motor', 'Temperature Sensor'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Gripper', '3D Printer'],
#  ['Robotic Arm', '3D Printer'],
#  ['Resistor', 'Power Supply', 'Robotic Arm', 'Gripper'],
#  ['PLC Controller'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Resistor', '3D Printer', 'Gripper'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['12V DC Motor', 'Stepper Motor', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Proximity Sensor', 'Temperature Sensor', 'VFD Drive'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['Robotic Arm'],
#  ['Gripper'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Gripper', '3D Printer'],
#  ['Proximity Sensor', 'Temperature Sensor'],
#  ['VFD Drive'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Stepper Motor'],
#  ['Resistor', '10A Relay Switch', 'Robotic Arm', '3D Printer'],
#  ['Servo Motor Driver', 'Stepper Motor'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Power Supply', 'Resistor'],
#  ['Gripper'],
#  ['Gripper'],
#  ['12V DC Motor'],
#  ['VFD Drive'],
#  ['Pressure Sensor', 'Control Cabinet'],
#  ['10A Relay Switch', 'Robotic Arm', '3D Printer'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['Robotic Arm', '3D Printer'],
#  ['Stepper Motor', '12V DC Motor', 'PLC Controller', 'Control Cabinet'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Gripper'],
#  ['Stepper Motor', 'Servo Motor Driver', 'Control Cabinet'],
#  ['VFD Drive', 'Control Cabinet'],
#  ['Pressure Sensor', 'Temperature Sensor'],
#  ['Robotic Arm', 'Gripper'],
#  ['Stepper Motor', 'Pressure Sensor', 'Proximity Sensor'],
#  ['Servo Motor Driver', 'Stepper Motor', 'VFD Drive'],
#  ['Temperature Sensor', 'VFD Drive', 'PLC Controller'],
#  ['10A Relay Switch'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['VFD Drive', 'PLC Controller'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Servo Motor Driver', 'PLC Controller'],
#  ['Temperature Sensor', 'Proximity Sensor', 'VFD Drive'],
#  ['Servo Motor Driver'],
#  ['Robotic Arm', '3D Printer'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['PLC Controller', 'VFD Drive'],
#  ['12V DC Motor', 'Servo Motor Driver', 'VFD Drive'],
#  ['Robotic Arm'],
#  ['Servo Motor Driver'],
#  ['Servo Motor Driver'],
#  ['Robotic Arm', '3D Printer'],
#  ['Gripper'],
#  ['PLC Controller', 'VFD Drive'],
#  ['Resistor'],
#  ['Pressure Sensor', 'PLC Controller'],
#  ['VFD Drive'],
#  ['Resistor', 'Gripper', 'Robotic Arm'],
#  ['PLC Controller'],
#  ['PLC Controller'],
#  ['PLC Controller', 'VFD Drive'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Temperature Sensor'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Servo Motor Driver'],
#  ['12V DC Motor', 'Stepper Motor'],
#  ['10A Relay Switch'],
#  ['Stepper Motor', 'VFD Drive'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Pressure Sensor',
#   'Proximity Sensor'],
#  ['Pressure Sensor', 'Proximity Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Servo Motor Driver', 'VFD Drive'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Temperature Sensor', 'Proximity Sensor', 'VFD Drive', 'PLC Controller'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['Robotic Arm'],
#  ['VFD Drive'],
#  ['Gripper'],
#  ['Gripper', 'Robotic Arm'],
#  ['VFD Drive'],
#  ['Stepper Motor'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['PLC Controller', 'VFD Drive'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Power Supply'],
#  ['PLC Controller'],
#  ['Pressure Sensor', 'PLC Controller'],
#  ['Servo Motor Driver',
#   '12V DC Motor',
#   'Pressure Sensor',
#   'Temperature Sensor'],
#  ['Pressure Sensor', 'Proximity Sensor', 'VFD Drive', 'PLC Controller'],
#  ['Servo Motor Driver', 'Proximity Sensor'],
#  ['Resistor', 'Power Supply'],
#  ['Servo Motor Driver'],
#  ['10A Relay Switch', 'Resistor', 'Robotic Arm'],
#  ['Servo Motor Driver'],
#  ['Stepper Motor'],
#  ['Pressure Sensor', 'Control Cabinet'],
#  ['Gripper', 'Robotic Arm'],
#  ['Resistor', '10A Relay Switch'],
#  ['Power Supply', '3D Printer', 'Gripper'],
#  ['Power Supply', 'Gripper', 'Robotic Arm'],
#  ['Stepper Motor', 'Servo Motor Driver', 'Control Cabinet', 'VFD Drive'],
#  ['12V DC Motor', 'Servo Motor Driver', 'Control Cabinet', 'PLC Controller'],
#  ['3D Printer', 'Gripper'],
#  ['12V DC Motor', 'Stepper Motor', 'Pressure Sensor'],
#  ['Power Supply'],
#  ['Control Cabinet'],
#  ['10A Relay Switch', 'Robotic Arm'],
#  ['Gripper', '3D Printer'],
#  ['Proximity Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['Pressure Sensor', 'Proximity Sensor', 'PLC Controller'],
#  ['Resistor', '10A Relay Switch', '3D Printer', 'Gripper'],
#  ['Resistor', '10A Relay Switch'],
#  ['10A Relay Switch', 'Power Supply'],
#  ['VFD Drive'],
#  ['Gripper'],
#  ['Resistor'],
#  ['Temperature Sensor', 'Pressure Sensor'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Temperature Sensor'],
#  ['3D Printer', 'Gripper'],
#  ['Pressure Sensor'],
#  ['Control Cabinet'],
#  ['3D Printer'],
#  ['Pressure Sensor', 'Proximity Sensor'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['VFD Drive', 'PLC Controller'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['Control Cabinet'],
#  ['Servo Motor Driver'],
#  ['12V DC Motor'],
#  ['10A Relay Switch', 'Resistor'],
#  ['Stepper Motor', 'Proximity Sensor', 'Temperature Sensor'],
#  ['Stepper Motor', 'Pressure Sensor'],
#  ['Proximity Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['Servo Motor Driver', '12V DC Motor'],
#  ['Control Cabinet', 'VFD Drive'],
#  ['VFD Drive'],
#  ['PLC Controller'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['3D Printer', 'Robotic Arm'],
#  ['Resistor', '10A Relay Switch'],
#  ['12V DC Motor'],
#  ['Gripper'],
#  ['Temperature Sensor'],
#  ['Power Supply', 'Resistor'],
#  ['12V DC Motor', 'Servo Motor Driver'],
#  ['Pressure Sensor', 'Control Cabinet', 'PLC Controller'],
#  ['Servo Motor Driver', 'PLC Controller'],
#  ['Proximity Sensor', 'Pressure Sensor'],
#  ['Proximity Sensor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['PLC Controller', 'Control Cabinet'],
#  ['Power Supply'],
#  ['Stepper Motor', 'Control Cabinet'],
#  ['Stepper Motor',
#   'Servo Motor Driver',
#   'Proximity Sensor',
#   'Pressure Sensor'],
#  ['Stepper Motor', '12V DC Motor'],
#  ['Stepper Motor', 'Servo Motor Driver'],
#  ['Temperature Sensor', 'Pressure Sensor', 'Control Cabinet', 'VFD Drive'],
#  ['12V DC Motor', 'VFD Drive'],
#  ...]

# %%
te = TransactionEncoder()
te_ary = te.fit(baskets).transform(baskets)
df = pd.DataFrame(te_ary, columns=te.columns_)
df.head()
# Out:
#    10A Relay Switch  12V DC Motor  3D Printer  Control Cabinet  Gripper  \
# 0             False         False        True            False     True
# 1             False         False       False            False    False
# 2             False         False       False             True    False
# 3             False         False       False            False    False
# 4             False          True       False            False    False
#
#    PLC Controller  Power Supply  Pressure Sensor  Proximity Sensor  Resistor  \
# 0           False         False            False             False     False
# 1           False         False             True              True     False
# 2           False         False            False             False     False
# 3           False         False            False              True     False
# 4           False         False            False             False     False
#
#    Robotic Arm  Servo Motor Driver  Stepper Motor  Temperature Sensor  \
# 0        False               False          False               False
# 1        False               False          False               False
# 2        False               False          False               False
# 3        False                True           True                True
# 4        False                True          False               False
#
#    VFD Drive
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False

# %%
frequent_itemsets = apriori(df, min_support=0.01, use_colnames=True)

# %%
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1)
rules
# Out:
#              antecedents           consequents  antecedent support  \
# 0           (3D Printer)    (10A Relay Switch)            0.107567
# 1     (10A Relay Switch)          (3D Printer)            0.108167
# 2     (10A Relay Switch)             (Gripper)            0.108167
# 3              (Gripper)    (10A Relay Switch)            0.106567
# 4         (Power Supply)    (10A Relay Switch)            0.106900
# 5     (10A Relay Switch)        (Power Supply)            0.108167
# 6             (Resistor)    (10A Relay Switch)            0.103933
# 7     (10A Relay Switch)            (Resistor)            0.108167
# 8     (10A Relay Switch)         (Robotic Arm)            0.108167
# 9          (Robotic Arm)    (10A Relay Switch)            0.105267
# 10        (12V DC Motor)  (Servo Motor Driver)            0.143300
# 11  (Servo Motor Driver)        (12V DC Motor)            0.145167
# 12        (12V DC Motor)       (Stepper Motor)            0.143300
# 13       (Stepper Motor)        (12V DC Motor)            0.146133
# 14          (3D Printer)             (Gripper)            0.107567
# 15             (Gripper)          (3D Printer)            0.106567
# 16          (3D Printer)        (Power Supply)            0.107567
# 17        (Power Supply)          (3D Printer)            0.106900
# 18            (Resistor)          (3D Printer)            0.103933
# 19          (3D Printer)            (Resistor)            0.107567
# 20          (3D Printer)         (Robotic Arm)            0.107567
# 21         (Robotic Arm)          (3D Printer)            0.105267
# 22      (PLC Controller)     (Control Cabinet)            0.145733
# 23     (Control Cabinet)      (PLC Controller)            0.146500
# 24           (VFD Drive)     (Control Cabinet)            0.150200
# 25     (Control Cabinet)           (VFD Drive)            0.146500
# 26        (Power Supply)             (Gripper)            0.106900
# 27             (Gripper)        (Power Supply)            0.106567
# 28            (Resistor)             (Gripper)            0.103933
# 29             (Gripper)            (Resistor)            0.106567
# 30         (Robotic Arm)             (Gripper)            0.105267
# 31             (Gripper)         (Robotic Arm)            0.106567
# 32      (PLC Controller)           (VFD Drive)            0.145733
# 33           (VFD Drive)      (PLC Controller)            0.150200
# 34            (Resistor)        (Power Supply)            0.103933
# 35        (Power Supply)            (Resistor)            0.106900
# 36        (Power Supply)         (Robotic Arm)            0.106900
# 37         (Robotic Arm)        (Power Supply)            0.105267
# 38    (Proximity Sensor)     (Pressure Sensor)            0.147433
# 39     (Pressure Sensor)    (Proximity Sensor)            0.146567
# 40  (Temperature Sensor)     (Pressure Sensor)            0.146133
# 41     (Pressure Sensor)  (Temperature Sensor)            0.146567
# 42    (Proximity Sensor)  (Temperature Sensor)            0.147433
# 43  (Temperature Sensor)    (Proximity Sensor)            0.146133
# 44            (Resistor)         (Robotic Arm)            0.103933
# 45         (Robotic Arm)            (Resistor)            0.105267
# 46  (Servo Motor Driver)       (Stepper Motor)            0.145167
# 47       (Stepper Motor)  (Servo Motor Driver)            0.146133
#
#     consequent support   support  confidence      lift  leverage  conviction  \
# 0             0.108167  0.020100    0.186861  1.727527  0.008465    1.096778
# 1             0.107567  0.020100    0.185824  1.727527  0.008465    1.096119
# 2             0.106567  0.018800    0.173806  1.630959  0.007273    1.081384
# 3             0.108167  0.018800    0.176415  1.630959  0.007273    1.082868
# 4             0.108167  0.036433    0.340817  3.150850  0.024870    1.352937
# 5             0.106900  0.036433    0.336826  3.150850  0.024870    1.346705
# 6             0.108167  0.035333    0.339962  3.142942  0.024091    1.351184
# 7             0.103933  0.035333    0.326656  3.142942  0.024091    1.330772
# 8             0.105267  0.018767    0.173498  1.648173  0.007380    1.082554
# 9             0.108167  0.018767    0.178277  1.648173  0.007380    1.085322
# 10            0.145167  0.048833    0.340777  2.347487  0.028031    1.296728
# 11            0.143300  0.048833    0.336395  2.347487  0.028031    1.290979
# 12            0.146133  0.047000    0.327983  2.244411  0.026059    1.270603
# 13            0.143300  0.047000    0.321624  2.244411  0.026059    1.262869
# 14            0.106567  0.036733    0.341494  3.204507  0.025270    1.356757
# 15            0.107567  0.036733    0.344698  3.204507  0.025270    1.361866
# 16            0.106900  0.019567    0.181903  1.701615  0.008068    1.091679
# 17            0.107567  0.019567    0.183037  1.701615  0.008068    1.092379
# 18            0.107567  0.018633    0.179282  1.666702  0.007454    1.087381
# 19            0.103933  0.018633    0.173226  1.666702  0.007454    1.083811
# 20            0.105267  0.035467    0.329718  3.132217  0.024143    1.334861
# 21            0.107567  0.035467    0.336922  3.132217  0.024143    1.345895
# 22            0.146500  0.048367    0.331885  2.265425  0.027017    1.277474
# 23            0.145733  0.048367    0.330148  2.265425  0.027017    1.275306
# 24            0.146500  0.050633    0.337106  2.301065  0.028629    1.287536
# 25            0.150200  0.050633    0.345620  2.301065  0.028629    1.298634
# 26            0.106567  0.019067    0.178360  1.673693  0.007675    1.087378
# 27            0.106900  0.019067    0.178918  1.673693  0.007675    1.087711
# 28            0.106567  0.019067    0.183451  1.721466  0.007991    1.094158
# 29            0.103933  0.019067    0.178918  1.721466  0.007991    1.091324
# 30            0.106567  0.033933    0.322356  3.024923  0.022715    1.318440
# 31            0.105267  0.033933    0.318424  3.024923  0.022715    1.312741
# 32            0.150200  0.050200    0.344465  2.293374  0.028311    1.296345
# 33            0.145733  0.050200    0.334221  2.293374  0.028311    1.283109
# 34            0.106900  0.033900    0.326171  3.051175  0.022790    1.325410
# 35            0.103933  0.033900    0.317119  3.051175  0.022790    1.312185
# 36            0.105267  0.017867    0.167134  1.587724  0.006614    1.074283
# 37            0.106900  0.017867    0.169728  1.587724  0.006614    1.075671
# 38            0.146567  0.049867    0.338232  2.307700  0.028258    1.289626
# 39            0.147433  0.049867    0.340232  2.307700  0.028258    1.292222
# 40            0.146567  0.048600    0.332573  2.269090  0.027182    1.278692
# 41            0.146133  0.048600    0.331590  2.269090  0.027182    1.277459
# 42            0.146133  0.049833    0.338006  2.312996  0.028288    1.289840
# 43            0.147433  0.049833    0.341013  2.312996  0.028288    1.293753
# 44            0.105267  0.018733    0.180244  1.712259  0.007793    1.091463
# 45            0.103933  0.018733    0.177961  1.712259  0.007793    1.090053
# 46            0.146133  0.048167    0.331803  2.270546  0.026953    1.277866
# 47            0.145167  0.048167    0.329608  2.270546  0.026953    1.275124
#
#     zhangs_metric
# 0        0.471898
# 1        0.472216
# 2        0.433785
# 3        0.433008
# 4        0.764332
# 5        0.765418
# 6        0.760911
# 7        0.764523
# 8        0.440965
# 9        0.439536
# 10       0.670028
# 11       0.671491
# 12       0.647191
# 13       0.649339
# 14       0.770858
# 15       0.769995
# 16       0.462021
# 17       0.461676
# 18       0.446410
# 19       0.448227
# 20       0.762788
# 21       0.760827
# 22       0.653873
# 23       0.654460
# 24       0.665355
# 25       0.662471
# 26       0.450698
# 27       0.450530
# 28       0.467711
# 29       0.469089
# 30       0.748170
# 31       0.749259
# 32       0.660170
# 33       0.663640
# 34       0.750231
# 35       0.752724
# 36       0.414475
# 37       0.413718
# 38       0.664661
# 39       0.663986
# 40       0.655014
# 41       0.655347
# 42       0.665825
# 43       0.664811
# 44       0.464224
# 45       0.464916
# 46       0.654604
# 47       0.655345

# %%
rules.to_pickle('./models/apriori_ruleset.pkl')
