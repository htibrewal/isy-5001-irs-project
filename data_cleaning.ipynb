# %%
# Import necessary libraries
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the dataset
file_path = './tvae_synthetic_dataset.csv'
data = pd.read_csv(file_path)

# Display the first few rows of the dataset
data.head()

# Check for missing values
missing_values = data.isnull().sum()

# print column names
print(data.columns)
# Out:
# Index(['#', 'DOCRATE', 'PO_NUM', 'BASE_NUMBER', 'BASE_LINE', 'PO_VALUE',
#        'ORDERED_QUANTITY', 'PRICE', 'ITEM_VALUE', 'FREIGHT', 'TAX_AMOUNT(LC)',
#        'LINETOTAL_WITH_TAX_(LC)', 'BALANCE_QUNATITY', 'OPEN_QTY_IN_OPENING',
#        'OPEN_ITEM_VALUE', 'ORDER_QTY', 'GRN_/_SHIPMENT_QTY',
#        'GRN_/_SHIPMENT_VAL', 'DOWNPAYMENT_VALUE', 'PAID_AMOUNT', 'OPEN_GR_QTY',
#        'GR_OPEN_VALUE', 'COST_SAVING', 'FORCE_CLOSED_PO_QTY', 'PART_ID',
#        'PART_REVISION', 'PRODUCT_GROUP', 'PRODUCT_SUBGROUP', 'WIDTH_(MM)',
#        'HEIGHT_(MM)', 'DEPTH_(MM)', 'WEIGHT_(KG)', 'DOCTYPE', 'CANCELED',
#        'DOCCUR', 'DOCSTATUS', 'BASE_TYPE', 'SUPPLIER_NAME', 'SUPPLIER_CODE',
#        'DOC_DATE', 'DELIVERY_DATE', 'BUYER', 'BP_PROJECT_CODE',
#        'BP_PROJECT_NAME', 'LINE_PROJECT_CODE', 'LINE_PROJECT_NAME', 'LOCATION',
#        'ITEM_CODE', 'ITEM_NAME', 'FG_ITEM_DESCRIPTION', 'ITEM_DETAILS',
#        'MANUFACTURER_PART_NO', 'HSN', 'UOM', 'TAX_CODE', 'USER_CODE',
#        'DOWNPAYMENT_DATE', 'MANUALLY_CLOSED_PO', 'PO_OWNER_NAME', 'PYMNTGROUP',
#        'HEADER', 'FOOTER', 'BRANCH_NAME', 'IMP_OR_EXP', 'COST_SAVING_CRITERIA',
#        'PART_NAME', 'PART_DESCRIPTION', 'PART_OWNER', 'REVISION_DATE',
#        'MANUFACTURER', 'MANUFACTURER_PART_NUMBER', 'EPLAN_PART_NUMBER',
#        'RELEASED_STATUS', 'RELEASED_DATE', 'PART_CATEGORY'],
#       dtype='object')

# %%
# print the shape of the dataset
print("Dataset Shape: ", data.shape)

# print the data types of the columns
print(data.dtypes)

# print the summary statistics of the dataset
print(data.describe())
# Out:
# Dataset Shape:  (50000, 75)
# #                             int64
# DOCRATE                     float64
# PO_NUM                        int64
# BASE_NUMBER                   int64
# BASE_LINE                     int64
#                              ...
# MANUFACTURER_PART_NUMBER     object
# EPLAN_PART_NUMBER            object
# RELEASED_STATUS              object
# RELEASED_DATE                object
# PART_CATEGORY                object
# Length: 75, dtype: object
#                   #       DOCRATE        PO_NUM   BASE_NUMBER     BASE_LINE  \
# count  50000.000000  50000.000000  5.000000e+04  5.000000e+04  50000.000000
# mean   27940.460120      3.791708  1.534599e+08  1.980236e+08      2.443860
# std    15946.595956     14.883865  1.103219e+08  8.285468e+07      1.967589
# min        9.000000      0.725667  5.358600e+04  1.000080e+05      1.000000
# 25%    14735.250000      0.955578  4.521165e+05  2.320370e+08      1.000000
# 50%    28494.000000      0.998351  2.320291e+08  2.323268e+08      2.000000
# 75%    42574.000000      1.042324  2.326123e+08  2.325651e+08      4.000000
# max    50442.000000     86.227546  2.425306e+08  2.425506e+08     80.000000
#
#            PO_VALUE  ORDERED_QUANTITY          PRICE    ITEM_VALUE  \
# count  5.000000e+04      50000.000000   50000.000000  5.000000e+04
# mean   4.627289e+05         66.659768    4085.264321  5.207475e+04
# std    5.298642e+06        399.006017   12758.957013  1.582406e+05
# min    0.000000e+00          0.000000       0.010000  1.000000e-02
# 25%    0.000000e+00          3.000000     147.709353  4.933460e+03
# 50%    1.528425e+05         23.600000    1314.928456  2.375783e+04
# 75%    3.160421e+05         46.200000    2736.223138  4.481422e+04
# max    1.521065e+08      17072.500000  435095.757900  5.050209e+06
#
#             FREIGHT  ...   COST_SAVING  FORCE_CLOSED_PO_QTY       PART_ID  \
# count  50000.000000  ...  50000.000000         50000.000000  50000.000000
# mean       4.788482  ...   3216.151139             3.276168  26443.340140
# std        6.534102  ...    552.531450             4.695914  10549.330484
# min        0.000000  ...    588.540000             0.000000  14865.000000
# 25%        0.000000  ...   2845.120000             0.000000  17870.000000
# 50%        1.071142  ...   3216.615000             1.200000  25870.500000
# 75%        8.218057  ...   3586.260000             5.600000  32519.000000
# max       45.825956  ...   5700.400000           323.800000  64995.000000
#
#        PART_REVISION  PRODUCT_GROUP  PRODUCT_SUBGROUP    WIDTH_(MM)  \
# count        50000.0   50000.000000      50000.000000  50000.000000
# mean             0.0      13.377980         26.832760     19.352283
# std              0.0      13.448212         67.283144     62.167185
# min              0.0       0.000000          0.000000      0.000000
# 25%              0.0       4.000000          1.000000      0.000000
# 50%              0.0      10.000000          1.000000      1.200000
# 75%              0.0      20.000000          2.000000      3.180000
# max              0.0     129.000000        221.000000    786.840000
#
#         HEIGHT_(MM)    DEPTH_(MM)   WEIGHT_(KG)
# count  50000.000000  50000.000000  50000.000000
# mean      20.330965     15.326726      0.946544
# std       95.783273     21.373152      1.455059
# min        0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000
# 50%        0.628802      9.320000      0.006737
# 75%        3.646505     24.530000      1.584429
# max     3000.000000   1107.350000     34.340667
#
# [8 rows x 32 columns]

# %%
focus_columns = ['PO_NUM', 'ITEM_CODE', 'ITEM_NAME','SUPPLIER_NAME', 'SUPPLIER_CODE','ORDERED_QUANTITY', 'PRICE', 'PO_VALUE', 'DOWNPAYMENT_DATE','DELIVERY_DATE', 'PART_DESCRIPTION']
df = data[focus_columns]
print(df.shape)
df[0:].head(10)
# Out:
# (50000, 11)
#       PO_NUM ITEM_CODE                   ITEM_NAME  \
# 0      53586     14873                        wire
# 1  233001368   2744400                        ELCB
# 2     977417   2277700         Ethernet I/O module
# 3      53586     18054                       Cable
# 4  233033749   2656800             BUSBAR ALUMINUM
# 5      53586   2651200            Remote IO Module
# 6      53586     15215  Signal cable pre-assembled
# 7  232558996   5046100          CONNECTOR - DSUB15
# 8     701936     14972                     Antenna
# 9  231513996     18128                       Relay
#
#                                 SUPPLIER_NAME SUPPLIER_CODE  ORDERED_QUANTITY  \
# 0                         SECURITAS ENGINEERS      VD000471             275.9
# 1                         SECURITAS ENGINEERS      VD000471              57.8
# 2                  TAC Automation Pvt.Ltd- UP      VD002456              16.2
# 3                  IGUS INDIA PRIVATE LIMITED      VD000478              50.0
# 4                           MEERA ENTERPRISES      VD003901               9.7
# 5                        SICK INDIA Pvt. Ltd.      VD000068              36.6
# 6  Diagnostic Automation & Controls Pvt. Ltd.      VD000915               0.0
# 7                         NETWORK ELECTRONICS      VF003119              12.7
# 8  Diagnostic Automation & Controls Pvt. Ltd.      VD000915               5.5
# 9                        SUGI ELECTRONICS LLP      VD003613              15.5
#
#           PRICE      PO_VALUE DOWNPAYMENT_DATE DELIVERY_DATE  \
# 0    209.326401       0.00000        2/27/2023     6/10/2023
# 1   3886.681121  136381.01890        2/27/2023    11/30/2023
# 2  10244.522240  249007.25340        2/27/2023      2/2/2023
# 3   1300.563242  401538.87360        2/27/2023     3/30/2023
# 4      0.010000       0.00000        2/27/2023     2/10/2024
# 5    131.818981  250077.76870        2/27/2023     9/16/2022
# 6   1787.705356       0.00000        2/27/2023     9/18/2022
# 7      0.010000   28219.83158        2/27/2023     5/20/2024
# 8      0.010000  141159.11950        2/27/2023     8/10/2022
# 9   1560.619156       0.00000        2/27/2023    11/15/2023
#
#                                     PART_DESCRIPTION
# 0  Power and control cable; 3G4; 11.1 mm; 1,1 kV;...
# 1  Earth leakage circuit breaker - DPN N Vigi - 1...
# 2  Compact IP20 multiprotocol Ethernet I/O module...
# 3  DB25 male breakout cable with DB9 female and f...
# 4            BUSBAR 25X6MM ALUMINUM 2.5 MTR HINDALCO
# 5  Junction box M12, ports 8 SBL-08D12-KC05 SENS....
# 6  Power cable pre-assembled 6FX3002-5CK01-1BA0 4...
# 7  Low Profile Right Angle Adapter, HD15 Male / F...
# 8        SOMANET Circulo 9 IO Cable Kit (S-042_O-04)
# 9  Monitoring Safety Relay, Dual Input, 2 Dual Ch...

# %%
# data cleaning

# lower case ITEM_NAME values and remove leading/trailing whitespaces
df['ITEM_NAME'] = df['ITEM_NAME'].str.lower().str.strip()

# lower case SUPPLIER_NAME values and remove leading/trailing whitespaces
df['SUPPLIER_NAME'] = df['SUPPLIER_NAME'].str.lower().str.strip()

# change PRICE float precision to 2 decimal places
df['PRICE'] = df['PRICE'].round(2)

# change PO_VALUE float precision to 2 decimal places
df['PO_VALUE'] = df['PO_VALUE'].round(2)

# convert DOC_DATE and DELIVERY_DATE to datetime
df['DOWNPAYMENT_DATE'] = pd.to_datetime(df['DOWNPAYMENT_DATE'])
df['DELIVERY_DATE'] = pd.to_datetime(df['DELIVERY_DATE'])
# Out:
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['ITEM_NAME'] = df['ITEM_NAME'].str.lower().str.strip()
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['SUPPLIER_NAME'] = df['SUPPLIER_NAME'].str.lower().str.strip()
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PRICE'] = df['PRICE'].round(2)
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PO_VALUE'] = df['PO_VALUE'].round(2)
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DOWNPAYMENT_DATE'] = pd.to_datetime(df['DOWNPAYMENT_DATE'])
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2670402648.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DELIVERY_DATE'] = pd.to_datetime(df['DELIVERY_DATE'])

# %%
# basic data exploration
# check for unique values in the columns
unique_values = df.nunique()

print(unique_values)
# Out:
# PO_NUM              39871
# ITEM_CODE            1607
# ITEM_NAME             832
# SUPPLIER_NAME         163
# SUPPLIER_CODE         161
# ORDERED_QUANTITY     3658
# PRICE               37485
# PO_VALUE            36791
# DOWNPAYMENT_DATE       22
# DELIVERY_DATE         475
# dtype: int64

# %%
# check for duplicate rows
duplicate_rows = df.duplicated().sum()
print("Number of duplicate rows: ", duplicate_rows)
# Out:
# Number of duplicate rows:  0

# %%
df.describe()
# Out:
#              PO_NUM  ORDERED_QUANTITY          PRICE      PO_VALUE  \
# count  5.000000e+04      50000.000000   50000.000000  5.000000e+04
# mean   1.534599e+08         66.659768    4085.264331  4.627289e+05
# min    5.358600e+04          0.000000       0.010000  0.000000e+00
# 25%    4.521165e+05          3.000000     147.705000  0.000000e+00
# 50%    2.320291e+08         23.600000    1314.925000  1.528425e+05
# 75%    2.326123e+08         46.200000    2736.225000  3.160421e+05
# max    2.425306e+08      17072.500000  435095.760000  1.521065e+08
# std    1.103219e+08        399.006017   12758.957025  5.298642e+06
#
#                  DOWNPAYMENT_DATE               DELIVERY_DATE
# count                       50000                       50000
# mean   2023-02-27 05:01:45.984000  2023-09-27 22:57:23.328000
# min           2022-12-08 00:00:00         2022-01-30 00:00:00
# 25%           2023-02-27 00:00:00         2023-04-28 00:00:00
# 50%           2023-02-27 00:00:00         2023-12-15 00:00:00
# 75%           2023-02-27 00:00:00         2024-02-22 00:00:00
# max           2024-05-14 00:00:00         2024-12-31 00:00:00
# std                           NaN                         NaN

# %%
# calculate the number of suppliers for a different ITEM NAMEs
supplier_count = df.groupby('ITEM_NAME')['SUPPLIER_NAME'].nunique()
print(supplier_count)
# Out:
# ITEM_NAME
# 0.25 sq/mm wire white/blue                                                3
# 0.5 sq.mm single core cable - blue, lapp                                  2
# 0.5 sq/mm wire white/blue                                                 5
# 0.75 sq/mm wire white/blue                                                2
# 16 digital outputs, remote, modular i/o system                            2
#                                                                          ..
# wireharness battery                                                       4
# wireharness circuit                                                       2
# wiring duct 25*45                                                         4
# y connector                                                               1
# y-link for connection of single-channel dp slaves to s7-400h & as 410h    1
# Name: SUPPLIER_NAME, Length: 832, dtype: int64

# %%
# print items in the order of the highest number of suppliers
supplier_count = supplier_count.sort_values(ascending=False)
print(supplier_count)
# Out:
# ITEM_NAME
# contactor                                                                 61
# drive                                                                     47
# limit switch                                                              45
# relay                                                                     40
# controller                                                                40
#                                                                           ..
# heat sink                                                                  1
# classic 100 0.75 sqmm triple core pvc control cable                        1
# hybrid motor starter reversing control load :2.4a 3ph                      1
# software-server10c                                                         1
# y-link for connection of single-channel dp slaves to s7-400h & as 410h     1
# Name: SUPPLIER_NAME, Length: 832, dtype: int64

# %%
# replace the values in the DOWNPAYMENT_DATE column with random dates from 2021-01-01 to 2023-12-31
import random
import datetime

start_date = datetime.date(2021, 1, 1)
end_date = datetime.date(2023, 12, 31)

df['DOWNPAYMENT_DATE'] = [random.choice(pd.date_range(start_date, end_date)) for _ in range(len(df))]
df['DOWNPAYMENT_DATE'] = pd.to_datetime(df['DOWNPAYMENT_DATE'])

# replace the values in the DELIVERY_DATE column with dates with a range of 1 to 150 days from the DOWNPAYMENT_DATE
df['DELIVERY_DATE'] =  df['DOWNPAYMENT_DATE'].apply((lambda x: x+ datetime.timedelta(days=random.randint(1, 90))))  
df['DELIVERY_DATE'] = pd.to_datetime(df['DELIVERY_DATE'])


# add a column days to delivery
df['DAYS_TO_DELIVERY'] = (df['DELIVERY_DATE'] - df['DOWNPAYMENT_DATE']).dt.days

# check for negative values in the days_to_delivery column
negative_days = df[df['DAYS_TO_DELIVERY'] < 0]
print(negative_days)
# Out:
# Empty DataFrame
# Columns: [PO_NUM, ITEM_CODE, ITEM_NAME, SUPPLIER_NAME, SUPPLIER_CODE, ORDERED_QUANTITY, PRICE, PO_VALUE, DOWNPAYMENT_DATE, DELIVERY_DATE, DAYS_TO_DELIVERY]
# Index: []
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2654847291.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DOWNPAYMENT_DATE'] = [random.choice(pd.date_range(start_date, end_date)) for _ in range(len(df))]
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2654847291.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DOWNPAYMENT_DATE'] = pd.to_datetime(df['DOWNPAYMENT_DATE'])
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2654847291.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DELIVERY_DATE'] =  df['DOWNPAYMENT_DATE'].apply((lambda x: x+ datetime.timedelta(days=random.randint(1, 90))))
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2654847291.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DELIVERY_DATE'] = pd.to_datetime(df['DELIVERY_DATE'])
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/2654847291.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['DAYS_TO_DELIVERY'] = (df['DELIVERY_DATE'] - df['DOWNPAYMENT_DATE']).dt.days

# %%
# text processing on the PART_DESCRIPTION column
import re 
import nltk
import spacy
from nltk.corpus import stopwords
from nltk.corpus import wordnet

def lower_casing(sentence):
    new_sentence = sentence.lower()
    return new_sentence

def punctuation_removal(sentence):
    # Remove the all the punctuations except '
    new_sentence = re.sub(',|!|\?|\"|<|>|\(|\)|\[|\]|\{|\}|@|#|\+|\=|\-|\_|~|\&|\*|\^|%|\||\$|/|`|\.|\'',
                          '', sentence,count=0, flags=0)
    return new_sentence

def stopword_removal(sentence):
    stoplist = stopwords.words('english')
    new_sentence = [word for word in sentence if word not in stoplist]
    return new_sentence

def get_wordnet_pos(word):
    pack = nltk.pos_tag([word])
    tag = pack[0][1]
    if tag.startswith('J'):
        return wordnet.ADJ
    elif tag.startswith('V'):
        return wordnet.VERB
    elif tag.startswith('N'):
        return wordnet.NOUN
    elif tag.startswith('R'):
        return wordnet.ADV
    else:
        return None
    
def lemmatization(sentence):
    lemmatizer = nltk.stem.WordNetLemmatizer()
    new_sentence = [lemmatizer.lemmatize(word, get_wordnet_pos(word) or wordnet.NOUN) for word in sentence]

    return new_sentence

def tokenization(sentence):
    new_sentence = nltk.word_tokenize(sentence)
    return new_sentence


def text_preprocessing(raw_sentence):
    sentence = lower_casing(raw_sentence)
    sentence = punctuation_removal(sentence)
    sentence = tokenization(sentence)
    sentence = stopword_removal(sentence)
    sentence = lemmatization(sentence)
    return sentence

# apply the text preprocessing function to the PART_DESCRIPTION column
df['PART_DESCRIPTION'] = df['PART_DESCRIPTION'].apply(text_preprocessing)
# Out:
# /var/folders/4b/88gg9p197zqffw05srynbc140000gn/T/ipykernel_43086/18934206.py:57: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['PART_DESCRIPTION'] = df['PART_DESCRIPTION'].apply(text_preprocessing)

# %%
# calculate the average days to delivery for each item by a particular supplier
# group by ITEM_NAME and SUPPLIER_NAME and calculate the mean of the days_to_delivery column
# reset the index to make the groupby columns regular columns
# rename the columns

avg_days_to_delivery = df.groupby(['ITEM_NAME', 'SUPPLIER_NAME'])['DAYS_TO_DELIVERY'].mean().reset_index()
avg_days_to_delivery.columns = ['ITEM_NAME', 'SUPPLIER_NAME', 'AVG_DAYS_TO_DELIVERY']
avg_days_to_delivery.head(10)
# Out:
#                                   ITEM_NAME                  SUPPLIER_NAME  \
# 0                0.25 sq/mm wire white/blue       bhl power system pvt ltd
# 1                0.25 sq/mm wire white/blue  phoenix contact india pvt ltd
# 2                0.25 sq/mm wire white/blue            securitas engineers
# 3  0.5 sq.mm single core cable - blue, lapp  phoenix contact india pvt ltd
# 4  0.5 sq.mm single core cable - blue, lapp            securitas engineers
# 5                 0.5 sq/mm wire white/blue       bhl power system pvt ltd
# 6                 0.5 sq/mm wire white/blue          digi-key electronics.
# 7                 0.5 sq/mm wire white/blue     kinco electricshenzhenltd.
# 8                 0.5 sq/mm wire white/blue            rd energy solutions
# 9                 0.5 sq/mm wire white/blue            securitas engineers
#
#    AVG_DAYS_TO_DELIVERY
# 0             56.333333
# 1             35.000000
# 2             19.500000
# 3             26.000000
# 4             31.333333
# 5             33.000000
# 6             17.000000
# 7              4.000000
# 8             29.000000
# 9             69.800000

# %%
df.to_csv('tvae_synthetic_dataset_cleaned.csv', index=True)
