# %%
import numpy as np
import pandas as pd
import re
import os
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
non_ascii_replacement_dict = {
    '€': '<euro>',
    '¢': '<cent>',
    '₹': '<rupee>',
    '×': 'X',
    '²': '<pow2>',
    '³': '<pow3>',
    '™': '<trademark>',
    '®': '<registered>',
    '–': '<dash>'
}

# %%
def clean_text(text):
    if isinstance(text, str):
        text = text.replace('“', '"').replace('”', '"').replace('″', '"')
        text = text.replace('‘', "'").replace('’', "'")

        # replace space and 2 or more double quotes with one & remove space 
        text = re.sub(r'(\d)\s?""*', r'\1"', text)
        
        text = re.sub(r"\s?''", r'"', text)
       
        # replace degree sign with text
        text = re.sub(r'\s?°', r'<deg>', text)

        # replace the non-ascii characters in the dict with their defined replacement         
        for pattern, replace in non_ascii_replacement_dict.items():
            text = re.sub(re.escape(pattern), re.escape(replace), text)

        text = re.sub(r'[^\x00-\x7F]', '', text)    
    return text

# %%
def to_uppercase(text):
    if isinstance(text, str):
        text = text.upper()
    return text

# %%
def clean_item_code(value):
    # Pattern for 2 letters followed by 5 digits -> ^[A-Za-z]{2}\d{5}$

    value = re.sub(r'^0+', '', value)
    clean_value = value
    
    pattern = r'^(\d{5})(0*)$'
    match = re.search(pattern, value)

    if match:
        clean_value = match.group(1)

    return clean_value

# %% [markdown]
# ### Load and Clean Purchase Order Line Items Dataset

# %%
df = pd.read_excel(os.path.join(os.getenv('PURCHASE_ORDER_FOLDER_PATH'), 'Data 1.xlsx'))
df.columns = df.columns.str.replace(' ', '_').str.upper()

# %%
df
# Out:
#            # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS     PO_NUM BASE_TYPE  \
# 0      26968       I        N    INR      1.0         C  232431279        PR
# 1      42455       I        N    INR      1.0         C  232471206        PR
# 2      45582       S        N    INR      1.0         C  232472169        PR
# 3       9868       S        N    INR      1.0         C      72616        PR
# 4       9869       S        N    INR      1.0         C      72616        PR
# ...      ...     ...      ...    ...      ...       ...        ...       ...
# 50456  48133       I        N    INR      1.0         O  242504101        PR
# 50457  48134       I        N    INR      1.0         O  242504101        PR
# 50458  48135       I        N    INR      1.0         O  242504101        PR
# 50459  16606       I        N    INR      1.0         C      74346        PR
# 50460  16607       I        N    INR      1.0         C      74346        PR
#
#        BASE_NUMBER  BASE_LINE  ... MANUALLY_CLOSED_PO        PO_OWNER_NAME  \
# 0      232401368.0        1.0  ...                 No       Yoginder Kumar
# 1      232451256.0        1.0  ...                 No      Ashutosh Tiwari
# 2      232452086.0        1.0  ...                 No     Abhishek Chauhan
# 3         100150.0        1.0  ...                Yes        Aman Chambial
# 4         100150.0        2.0  ...                Yes        Aman Chambial
# ...            ...        ...  ...                ...                  ...
# 50456  242500075.0        6.0  ...                 No     Dheeraj Sachdeva
# 50457  242500075.0        4.0  ...                 No     Dheeraj Sachdeva
# 50458  242500075.0        3.0  ...                 No     Dheeraj Sachdeva
# 50459     102315.0        1.0  ...                 No  Sanket Singh Rathor
# 50460     102315.0        2.0  ...                 No  Sanket Singh Rathor
#
#                     PYMNTGROUP  \
# 0                  Net 30 days
# 1                  Net 30 days
# 2                Refer PO Text
# 3                       Net-30
# 4                       Net-30
# ...                        ...
# 50456              Net 30 days
# 50457              Net 30 days
# 50458              Net 30 days
# 50459  100% advance against PI
# 50460  100% advance against PI
#
#                                                   HEADER FOOTER BRANCH_NAME  \
# 0                                                    NaN    NaN       NOIDA
# 1                                                    NaN    NaN   Ecotech X
# 2      Payment Terms : 100% after service completion ...    NaN   Ecotech X
# 3      OTC charges shall be paid after installation o...    NaN       NOIDA
# 4      OTC charges shall be paid after installation o...    NaN       NOIDA
# ...                                                  ...    ...         ...
# 50456                                                NaN    NaN       NOIDA
# 50457                                                NaN    NaN       NOIDA
# 50458                                                NaN    NaN       NOIDA
# 50459  12 mtr weight is 948 kg (200*200)  140*90 it i...    NaN       NOIDA
# 50460  12 mtr weight is 948 kg (200*200)  140*90 it i...    NaN       NOIDA
#
#       IMP_OR_EXP  COST_SAVING COST_SAVING_CRITERIA FORCE_CLOSED_PO_QTY
# 0              N          NaN                  NaN                 0.0
# 1              N          NaN                  NaN                 0.0
# 2              N          NaN                  NaN                 0.0
# 3              N          NaN                  NaN                 0.0
# 4              N          NaN                  NaN                 0.0
# ...          ...          ...                  ...                 ...
# 50456          N          NaN                  NaN                 0.0
# 50457          N          NaN                  NaN                 0.0
# 50458          N          NaN                  NaN                 0.0
# 50459          N          NaN                  NaN                 0.0
# 50460          N          NaN                  NaN                 0.0
#
# [50461 rows x 59 columns]

# %%
df_cleaned = df.apply(lambda col: col.apply(clean_text))
df_cleaned = df_cleaned.apply(lambda col: col.apply(to_uppercase))

# %%
df_cleaned_nan = df_cleaned[df_cleaned['ITEM_CODE'].isna()].copy()
df_cleaned_nan
# Out:
#            # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS     PO_NUM BASE_TYPE  \
# 2      45582       S        N    INR      1.0         C  232472169        PR
# 3       9868       S        N    INR      1.0         C      72616        PR
# 4       9869       S        N    INR      1.0         C      72616        PR
# 5       9870       S        N    INR      1.0         C      72616        PR
# 6      22886       S        N    INR      1.0         C  232420215        PR
# ...      ...     ...      ...    ...      ...       ...        ...       ...
# 50271  37350       S        N    INR      1.0         C  232450057        PR
# 50272  37974       S        N    INR      1.0         O  232450263        PR
# 50273  37975       S        N    INR      1.0         O  232450263        PR
# 50274  37976       S        N    INR      1.0         O  232450263        PR
# 50373  41021       S        N    INR      1.0         O  232470766        PR
#
#        BASE_NUMBER  BASE_LINE  ... MANUALLY_CLOSED_PO         PO_OWNER_NAME  \
# 2      232452086.0        1.0  ...                 NO      ABHISHEK CHAUHAN
# 3         100150.0        1.0  ...                YES         AMAN CHAMBIAL
# 4         100150.0        2.0  ...                YES         AMAN CHAMBIAL
# 5         100150.0        3.0  ...                 NO         AMAN CHAMBIAL
# 6      232404753.0        1.0  ...                 NO         NEERAJ TIWARI
# ...            ...        ...  ...                ...                   ...
# 50271  232440055.0        4.0  ...                 NO      DHEERAJ SACHDEVA
# 50272  232440259.0        1.0  ...                 NO  SANDEEP KUMAR GAUTAM
# 50273  232440259.0        2.0  ...                 NO  SANDEEP KUMAR GAUTAM
# 50274  232440259.0        3.0  ...                 NO  SANDEEP KUMAR GAUTAM
# 50373  232450775.0        2.0  ...                 NO           POOJA YADAV
#
#           PYMNTGROUP                                             HEADER  \
# 2      REFER PO TEXT  PAYMENT TERMS : 100% AFTER SERVICE COMPLETION ...
# 3             NET-30  OTC CHARGES SHALL BE PAID AFTER INSTALLATION O...
# 4             NET-30  OTC CHARGES SHALL BE PAID AFTER INSTALLATION O...
# 5             NET-30  OTC CHARGES SHALL BE PAID AFTER INSTALLATION O...
# 6             NET-30                                                NaN
# ...              ...                                                ...
# 50271    NET 30 DAYS  IF ZOOM CONTACT CENTER CLOUD STORAGE 200GB REQ...
# 50272    NET 30 DAYS                                                NaN
# 50273    NET 30 DAYS                                                NaN
# 50274    NET 30 DAYS                                                NaN
# 50373   100% ADVANCE                                                NaN
#
#       FOOTER BRANCH_NAME IMP_OR_EXP  COST_SAVING COST_SAVING_CRITERIA  \
# 2        NaN   ECOTECH X          N          NaN                  NaN
# 3        NaN       NOIDA          N          NaN                  NaN
# 4        NaN       NOIDA          N          NaN                  NaN
# 5        NaN       NOIDA          N          NaN                  NaN
# 6        NaN       NOIDA          N          NaN                  NaN
# ...      ...         ...        ...          ...                  ...
# 50271    NaN    AFSNOIDA          N          NaN                  NaN
# 50272    NaN    AFSNOIDA          N          NaN                  NaN
# 50273    NaN    AFSNOIDA          N          NaN                  NaN
# 50274    NaN    AFSNOIDA          N          NaN                  NaN
# 50373    NaN   ECOTECH X          N          NaN                  NaN
#
#       FORCE_CLOSED_PO_QTY
# 2                     0.0
# 3                     0.0
# 4                     0.0
# 5                     0.0
# 6                     0.0
# ...                   ...
# 50271                 0.0
# 50272                 0.0
# 50273                 0.0
# 50274                 0.0
# 50373                 0.0
#
# [5252 rows x 59 columns]

# %%
df_cleaned_non_nan = df_cleaned[df_cleaned['ITEM_CODE'].notna()].copy()
df_cleaned_non_nan.shape
# Out:
# (45209, 59)

# %%
df_cleaned_non_nan['ITEM_CODE_CLEANED'] = df_cleaned_non_nan['ITEM_CODE'].astype(str).apply(clean_item_code)
df_cleaned_non_nan[['ITEM_CODE', 'ITEM_CODE_CLEANED']]
# Out:
#        ITEM_CODE ITEM_CODE_CLEANED
# 0        MC11560           MC11560
# 1        4556800             45568
# 11       ST00545           ST00545
# 12       ST00546           ST00546
# 13       GC01436           GC01436
# ...          ...               ...
# 50456  00047513A            47513A
# 50457  00047494A            47494A
# 50458  00047510A            47510A
# 50459    3079000             30790
# 50460    3079100             30791
#
# [45209 rows x 2 columns]

# %%
po_grouped_df = df_cleaned_nan.groupby('PO_NUM')['ITEM_CODE'].apply(lambda x: x.isna().sum())

# count PO_NUN having >= 1 NaN ITEM_CODE and count individual NaN ITEM_CODE
po_count = (po_grouped_df > 0).sum()
item_code_count = po_grouped_df.sum()

print(po_count, item_code_count)
# Out:
# 2462 5252

# %%
def keep_most_quantity(group):
    return group.loc[group['ORDERED_QUANTITY'].idxmax()]

# %%
# df_cleaned_filtered = df_cleaned_non_nan.drop_duplicates(subset=['PO_NUM', 'ITEM_CODE_CLEANED'], keep='first')

# grouping by the columns and keeping the row with most ordered quantity - WAY TO DROP DUPLICATE WITH CUSTOM LOGIC
non_nan_filtered = df_cleaned_non_nan.groupby(['PO_NUM', 'ITEM_CODE_CLEANED']).apply(keep_most_quantity).reset_index(drop=True)
non_nan_filtered.shape
# Out:
# /var/folders/4c/99wh1f85111309s8ydsfjmlr0000gn/T/ipykernel_36825/1667788486.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   non_nan_filtered = df_cleaned_non_nan.groupby(['PO_NUM', 'ITEM_CODE_CLEANED']).apply(keep_most_quantity).reset_index(drop=True)
# (42159, 60)

# %% [markdown]
# #### Find repeated Supplier Name against Supplier Code

# %%
def find_repeating_supplier_names(target_df):
    multiple_codes = target_df.groupby('SUPPLIER_NAME')['SUPPLIER_CODE'].unique()
    problematic_names = multiple_codes[multiple_codes.apply(lambda codes: len(codes) > 1)]
    return problematic_names

# %%
find_repeating_supplier_names(df_cleaned_non_nan)
# Out:
# SUPPLIER_NAME
# ALPINE INDUSTRIAL SOLUTION                                                    [VCD000045, VD002001]
# BAR CODE INDIA LIMITED                                                         [VD001568, VO000095]
# DIGI-KEY ELECTRONICS..                                                         [VF010009, VO000101]
# DISA INDIA LIMITED                                                            [VCD000027, VD004153]
# ELECTROMECH FIRE FIGHTERS PVT. LTD.                                           [VCD000012, VD001831]
# EVOKE GLOBAL                                                                  [VCD000116, VD003868]
# GAINWELL COMMOSALES PRIVATE LIMITED                                           [VCD000011, VD004294]
# GURUJI STEEL TRADING                                                          [VD002397, VCD000106]
# INDOTECH ENGINEERS                                                            [VCD000136, VD002923]
# IRUS ENGINEERING PVT LTD                                                      [VCD000037, VD003776]
# JPS ENGINEERS                                                                 [VD000514, VCD000042]
# KONECRANES AND DEMAG PRIVATE LIMITED                                           [VD001544, VD001567]
# MB ENTERPRISE                                                                 [VCD000066, VD004226]
# MGM VARVEL POWER TRANSMISSION PVT LTD                                          [VD001767, VD001695]
# MIAS MATERIALS HANDLING (KUNSHAN) CO. LTD.                                    [VCF000040, VF001874]
# MOUSER ELECTRONICS                                                             [VF000366, VD000073]
# MST MANUFACTURING SOLUTIONS PRIVATE LIMITED                                    [VD001820, VD001761]
# MULTICUT MACHINE TOOLS                                                        [VCD000052, VD001666]
# NEONICA PRINTERS                                                               [VD000005, VD000569]
# NILKAMAL LIMITED                                         [VCD000125, VCD000126, VD003879, VO000094]
# PRAJA CONTROLS & SYSTEMS PVT LTD                                              [VCD000056, VD002495]
# RM KITCHEN EQUIPMENTS PVT. LTD.                                               [VCD000122, VD004115]
# ROOTS MULTICLEAN LTD                                                          [VCD000117, VD002728]
# SEW EURODRIVE INDIA P LTD                                                     [VCD000130, VD003949]
# SHRI BALAJI TRADERS                                                           [VCD000019, VD002093]
# SPARKH ENGINEERS & TECHNOLOGIES                                               [VCD000109, VD001880]
# TEKNICS INDIA                                                                 [VCD000138, VD003878]
# TOSHIBA INDIA PVT LTD                                                         [VD000223, VLC002025]
# TREEZY CARBON SINK PRIVATE LIMITED                                            [VCD000057, VD004043]
# VANTAGE INTEGRATED SECURITY SOLUTIONS PRIVATE LIMITED                         [VD002270, VCD000038]
# VARIETY INNOVATION VENTURE PVT LTD                                            [VCD000067, VD003345]
# ZERO DEGREE HVAC SOLUTIONS                                                    [VCD000104, VD001689]
# Name: SUPPLIER_CODE, dtype: object

# %%
# df_cleaned_non_nan[df_cleaned_non_nan['SUPPLIER_CODE'].isin(['VD000223', 'VLC002025'])]
df_cleaned_non_nan[df_cleaned_non_nan['SUPPLIER_CODE'].isin(['VCD000130', 'VD003949'])]
# Out:
#            # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS     PO_NUM BASE_TYPE  \
# 39678   4514       I        N    INR      1.0         O      60330        PR
# 39679   4515       I        N    INR      1.0         O      60330        PR
# 39680   4516       I        N    INR      1.0         O      60330        PR
# 39681   4517       I        N    INR      1.0         O      60330        PR
# 39682   4518       I        N    INR      1.0         O      60330        PR
# ...      ...     ...      ...    ...      ...       ...        ...       ...
# 39886  49264       I        N    INR      1.0         C  242530222        PR
# 39887  49354       I        N    INR      1.0         O  242530260        PR
# 39888  49549       I        N    INR      1.0         O  242530332        PR
# 39889  50002       I        N    INR      1.0         O  242530517        PR
# 39890  50080       I        N    INR      1.0         O  242530545        PR
#
#        BASE_NUMBER  BASE_LINE  ...       PO_OWNER_NAME   PYMNTGROUP  \
# 39678     102638.0       18.0  ...    PRIYANSHI SAXENA  NET 45 DAYS
# 39679     102638.0       17.0  ...    PRIYANSHI SAXENA  NET 45 DAYS
# 39680     102638.0        1.0  ...    PRIYANSHI SAXENA  NET 45 DAYS
# 39681     102638.0        2.0  ...    PRIYANSHI SAXENA  NET 45 DAYS
# 39682     102638.0        3.0  ...    PRIYANSHI SAXENA  NET 45 DAYS
# ...            ...        ...  ...                 ...          ...
# 39886  242550194.0        1.0  ...     ASHUTOSH TIWARI  NET 30 DAYS
# 39887  242550031.0        2.0  ...  SHOBHIT KHANDELWAL  NET 30 DAYS
# 39888  242550207.0       21.0  ...  SHOBHIT KHANDELWAL  NET 30 DAYS
# 39889  242550401.0        3.0  ...     ASHUTOSH TIWARI  NET 30 DAYS
# 39890  242550411.0       12.0  ...    DHEERAJ SACHDEVA  NET 30 DAYS
#
#                                                   HEADER FOOTER BRANCH_NAME  \
# 39678  CONTACT DETAILS: MR. MANI BHUSHAN JHA M/S SEW-...    NaN       NOIDA
# 39679  CONTACT DETAILS: MR. MANI BHUSHAN JHA M/S SEW-...    NaN       NOIDA
# 39680  CONTACT DETAILS: MR. MANI BHUSHAN JHA M/S SEW-...    NaN       NOIDA
# 39681  CONTACT DETAILS: MR. MANI BHUSHAN JHA M/S SEW-...    NaN       NOIDA
# 39682  CONTACT DETAILS: MR. MANI BHUSHAN JHA M/S SEW-...    NaN       NOIDA
# ...                                                  ...    ...         ...
# 39886                                                NaN    NaN   ECOTECH X
# 39887                                                NaN    NaN   ECOTECH X
# 39888                                                NaN    NaN   ECOTECH X
# 39889                                                NaN    NaN   ECOTECH X
# 39890                                                NaN    NaN   ECOTECH X
#
#       IMP_OR_EXP COST_SAVING  COST_SAVING_CRITERIA FORCE_CLOSED_PO_QTY  \
# 39678          N         NaN                   NaN                 0.0
# 39679          N         NaN                   NaN                 0.0
# 39680          N         NaN                   NaN                 0.0
# 39681          N         NaN                   NaN                 0.0
# 39682          N         NaN                   NaN                 0.0
# ...          ...         ...                   ...                 ...
# 39886          N         NaN                   NaN                 0.0
# 39887          N         NaN                   NaN                 0.0
# 39888          N         NaN                   NaN                 0.0
# 39889          N         NaN                   NaN                 0.0
# 39890          N         NaN                   NaN                 0.0
#
#       ITEM_CODE_CLEANED
# 39678             29329
# 39679             29330
# 39680             28827
# 39681             28828
# 39682             28829
# ...                 ...
# 39886             45897
# 39887             52950
# 39888             17070
# 39889             38631
# 39890             40930
#
# [207 rows x 60 columns]

# %% [markdown]
# #### Find and Analyse Duplicates

# %%
duplicates = df_cleaned_non_nan[df_cleaned_non_nan.duplicated(subset=['PO_NUM', 'ITEM_CODE_CLEANED'], keep=False)]
columns_to_check = ['DOC_DATE', 'DELIVERY_DATE', 'PO_VALUE', 'ORDERED_QUANTITY', 'PRICE', 'ITEM_VALUE', 'FREIGHT', 'TAX_AMOUNT(LC)']

differences = duplicates.groupby(['PO_NUM', 'ITEM_CODE_CLEANED']).apply(lambda group: group[columns_to_check].nunique() > 1)
# differences = differences[differences.any(axis=1)]
differences
# Out:
# /var/folders/4c/99wh1f85111309s8ydsfjmlr0000gn/T/ipykernel_33498/314100391.py:4: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   differences = duplicates.groupby(['PO_NUM', 'ITEM_CODE_CLEANED']).apply(lambda group: group[columns_to_check].nunique() > 1)
#                              DOC_DATE  DELIVERY_DATE  PO_VALUE  \
# PO_NUM    ITEM_CODE_CLEANED
# 53985     17379                 False          False     False
# 54483     MC1547                False          False     False
# 54813     HK00108               False          False     False
# 55053     ELC10377              False          False     False
# 55376     EL13183               False          False     False
# ...                               ...            ...       ...
# 242530533 18748                 False          False     False
#           22798                 False          False     False
#           3765                  False          False     False
# 242530581 17888                 False          False     False
#           26777                 False          False     False
#
#                              ORDERED_QUANTITY  PRICE  ITEM_VALUE  FREIGHT  \
# PO_NUM    ITEM_CODE_CLEANED
# 53985     17379                          True  False        True    False
# 54483     MC1547                        False  False       False    False
# 54813     HK00108                        True  False        True    False
# 55053     ELC10377                       True   True        True    False
# 55376     EL13183                        True  False        True    False
# ...                                       ...    ...         ...      ...
# 242530533 18748                          True  False        True    False
#           22798                          True  False        True    False
#           3765                           True  False        True    False
# 242530581 17888                          True  False        True    False
#           26777                         False  False       False    False
#
#                              TAX_AMOUNT(LC)
# PO_NUM    ITEM_CODE_CLEANED
# 53985     17379                        True
# 54483     MC1547                      False
# 54813     HK00108                      True
# 55053     ELC10377                    False
# 55376     EL13183                      True
# ...                                     ...
# 242530533 18748                        True
#           22798                        True
#           3765                         True
# 242530581 17888                        True
#           26777                       False
#
# [2371 rows x 8 columns]

# %%
df_cleaned_non_nan[(df_cleaned_non_nan['PO_NUM'] == 53985) & (df_cleaned_non_nan['ITEM_CODE_CLEANED'] == '17379')]
# Out:
#         # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS  PO_NUM BASE_TYPE  \
# 30720  24       I        N    INR      1.0         C   53985        -1
# 30721  25       I        N    INR      1.0         C   53985        -1
# 30722  26       I        N    INR      1.0         C   53985        -1
#
#        BASE_NUMBER  BASE_LINE  ...         PO_OWNER_NAME PYMNTGROUP  \
# 30720          NaN        NaN  ...  AKUL PRABHAKAR KADAM     NET-30
# 30721          NaN        NaN  ...  AKUL PRABHAKAR KADAM     NET-30
# 30722          NaN        NaN  ...  AKUL PRABHAKAR KADAM     NET-30
#
#                                                   HEADER FOOTER BRANCH_NAME  \
# 30720  ACTUAL PRICE FOR 00017381 IS 600, WE HAVE AMEN...    NaN       NOIDA
# 30721  ACTUAL PRICE FOR 00017381 IS 600, WE HAVE AMEN...    NaN       NOIDA
# 30722  ACTUAL PRICE FOR 00017381 IS 600, WE HAVE AMEN...    NaN       NOIDA
#
#       IMP_OR_EXP COST_SAVING  COST_SAVING_CRITERIA FORCE_CLOSED_PO_QTY  \
# 30720          N         NaN                   NaN                 0.0
# 30721          N         NaN                   NaN                 0.0
# 30722          N         NaN                   NaN                 0.0
#
#       ITEM_CODE_CLEANED
# 30720             17379
# 30721             17379
# 30722             17379
#
# [3 rows x 60 columns]

# %%
df_cleaned_non_nan[(df_cleaned_non_nan['PO_NUM'] == 55053) & (df_cleaned_non_nan['ITEM_CODE_CLEANED'] == 'ELC10377')]
# Out:
#         # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS  PO_NUM BASE_TYPE  \
# 4351  184       I        N    USD    75.73         C   55053        -1
# 4352  185       I        N    USD    75.73         C   55053        -1
#
#       BASE_NUMBER  BASE_LINE  ... PO_OWNER_NAME PYMNTGROUP HEADER FOOTER  \
# 4351          NaN        NaN  ...       KIRAN -     NET-30    NaN    NaN
# 4352          NaN        NaN  ...       KIRAN -     NET-30    NaN    NaN
#
#      BRANCH_NAME IMP_OR_EXP COST_SAVING  COST_SAVING_CRITERIA  \
# 4351       NOIDA          Y         NaN                   NaN
# 4352       NOIDA          Y         NaN                   NaN
#
#      FORCE_CLOSED_PO_QTY ITEM_CODE_CLEANED
# 4351             36000.0          ELC10377
# 4352              9000.0          ELC10377
#
# [2 rows x 60 columns]

# %% [markdown]
# ### Load and Clean Electrical Parts Catalogue Dataset

# %%
electrical_parts = pd.read_csv(
    os.path.join(os.getenv('ELECTRICAL_PARTS_FOLDER_PATH'), 'Electrical Parts Report Modified.csv'),
)
electrical_parts.columns = electrical_parts.columns.str.replace(' ', '_').str.upper()

# %%
electrical_parts.shape
# Out:
# (9359, 21)

# %%
electrical_parts_cleaned = pd.DataFrame(electrical_parts.apply(lambda col: col.apply(clean_text)))
electrical_parts_cleaned = electrical_parts_cleaned.apply(lambda col: col.apply(to_uppercase))

# %%
electrical_parts_cleaned['PART_ID_CLEANED'] = electrical_parts_cleaned['PART_ID'].astype(str).apply(clean_item_code)
electrical_parts_cleaned[['PART_ID', 'PART_ID_CLEANED']]
# Out:
#       PART_ID PART_ID_CLEANED
# 0       41237           41237
# 1       52897           52897
# 2       54675           54675
# 3       57680           57680
# 4       64912           64912
# ...       ...             ...
# 9354    46980           46980
# 9355    46984           46984
# 9356    46987           46987
# 9357    46985           46985
# 9358    46986           46986
#
# [9359 rows x 2 columns]

# %%
electrical_parts_cleaned[electrical_parts_cleaned.duplicated(subset='PART_ID_CLEANED', keep=False)].sort_values(['PART_ID_CLEANED', 'PART_REVISION'])
# Out:
#       PART_ID                                          PART_NAME  \
# 8498    14948                                     TERMINAL BLOCK
# 8576    14948  TERMINAL BLOCKS SD,CROSS SECTION (0.5 - 10SQMM...
# 4338    15244                                 DISTRIBUTION BLOCK
# 4343    15244                                 DISTRIBUTION BLOCK
# 4937    17190                                  FLIGHT CONTROLLER
# 4938    17190                                  FLIGHT CONTROLLER
# 5706    17437                                              LIDAR
# 5715    17437  LIDAR-1D,COMMUNICATION PROTOCOL (UART), NON SA...
# 795     18274                                            ANTENNA
# 810     18274          ANTENNA-OMNIDIRECTIONAL,2.4 & 5GHZ, 3.2DB
# 7250    18749                                        PUSH BUTTON
# 7264    18749                               PUSH BUTTON- 1NC,RED
# 4263    24552                                    DC-DC CONVERTER
# 4106    24552      CONVERTER-DC TO DC, 9-36V DC TO 5V DC, 6000MA
# 8472    25674                                           TERMINAL
# 7935    25674                       SHORTING LINK , 6.2 MM, GRAY
#
#                                        PART_DESCRIPTION  \
# 8498  MINI FEED-THROUGH TERMINAL BLOCK, NOM. VOLTAGE...
# 8576  MINI FEED-THROUGH TERMINAL BLOCK CROSS SECTION...
# 4338  DISTRIBUTION BLOCK, NOMINAL CURRENT: 41 A, CON...
# 4343  DISTRIBUTION BLOCK, NOMINAL CURRENT: 41 A, CON...
# 4937                     AIKON F42020 FLIGHT CONTROLLER
# 4938                     AIKON F42020 FLIGHT CONTROLLER
# 5706  SINGLE POINT LIDAR, 0.05M TO 40M, FOV 3 DEGREE...
# 5715  SINGLE POINT LIDAR, 0.05M TO 40M, FOV 3 DEGREE...
# 795   ANTENNAS 2.4GHZ/5GHZ WRT SERIES LOW PROFILE DO...
# 810   ANTENNAS 2.4GHZ/5GHZ WRT SERIES LOW PROFILE DO...
# 7250  RED ILLUMINATED MUSHROOM HEAD PUSHBUTTON WITH ...
# 7264  RED ILLUMINATED MUSHROOM HEAD PUSHBUTTON WITH ...
# 4263              24V TO 5V, 6A STEP DOWN REGULATOR 30W
# 4106              24V TO 5V, 6A STEP DOWN REGULATOR 30W
# 8472       INSERTION BRIDGE, PITCH: 6.2 MM, COLOR: GRAY
# 7935  INSERTION BRIDGE, PITCH: 6.2 MM, NUMBER OF POS...
#
#                         PART_OWNER  PART_REVISION      REVISION_DATE  \
# 8498  KUMARI MONIKA (KUMARIMONIKA)              0  18-OCT-2022 11:36
# 8576  KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:32
# 4338  KUMARI MONIKA (KUMARIMONIKA)              0  18-OCT-2022 11:38
# 4343  KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:08
# 4937  KUMARI MONIKA (KUMARIMONIKA)              0  19-OCT-2022 15:46
# 4938  KUMARI MONIKA (KUMARIMONIKA)              1  05-DEC-2023 13:40
# 5706  KUMARI MONIKA (KUMARIMONIKA)              0  19-OCT-2022 15:48
# 5715  KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:06
# 795   KUMARI MONIKA (KUMARIMONIKA)              0  21-OCT-2022 10:15
# 810   KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:41
# 7250  KUMARI MONIKA (KUMARIMONIKA)              0  21-OCT-2022 19:14
# 7264  KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:37
# 4263  KUMARI MONIKA (KUMARIMONIKA)              0  07-NOV-2022 18:11
# 4106  KUMARI MONIKA (KUMARIMONIKA)              1  19-AUG-2023 10:29
# 8472  KUMARI MONIKA (KUMARIMONIKA)              0  19-NOV-2022 20:56
# 7935  KUMARI MONIKA (KUMARIMONIKA)              1  22-SEP-2023 18:09
#
#       PRODUCT_GROUP  PRODUCT_SUBGROUP  WIDTH_(MM)  HEIGHT_(MM)  ...  \
# 8498            3.0               1.0         0.0          0.0  ...
# 8576            3.0               1.0         0.0          0.0  ...
# 4338            3.0               1.0         0.0          0.0  ...
# 4343            3.0               1.0         0.0          0.0  ...
# 4937           19.0               1.0         0.0          0.0  ...
# 4938           19.0               1.0         0.0          0.0  ...
# 5706           12.0               1.0         0.0          0.0  ...
# 5715           12.0               1.0         0.0          0.0  ...
# 795             8.0               1.0         0.0          0.0  ...
# 810             8.0               1.0         0.0          0.0  ...
# 7250           12.0               1.0         0.0          0.0  ...
# 7264           12.0               1.0         0.0          0.0  ...
# 4263           20.0               1.0         0.0          0.0  ...
# 4106           20.0               1.0        31.5         21.2  ...
# 8472            1.0               1.0         NaN          NaN  ...
# 7935            1.0               1.0         0.0          0.0  ...
#
#       WEIGHT_(KG)  MANUFACTURER  MANUFACTURER_PART_NUMBER  \
# 8498          0.0     PHOENIX.C                    552024
# 8576          0.0     PHOENIX.C                    552024
# 4338          0.0     PHOENIX.C                   1046985
# 4343          0.0     PHOENIX.C                   1046985
# 4937          0.0         AIKON                    F42020
# 4938          0.0         AIKON                    F42020
# 5706          0.0      BENEWAKE                   TF02PRO
# 5715          0.0      BENEWAKE                   TF02PRO
# 795           0.0        LINX.T           ANT-DB1-WRT-RPS
# 810           0.0        LINX.T           ANT-DB1-WRT-RPS
# 7250          0.0     SCHNEIDER                XB5AW74B2N
# 7264          0.0     SCHNEIDER                XB5AW74B2N
# 4263          0.0         CUI.I         PYBE30-Q24-S5-DIN
# 4106          0.0         CUI.I         PYBE30-Q24-S5-DIN
# 8472          NaN     PHEONIX.C                    201139
# 7935          0.0     PHOENIX.C                    201139
#
#           EPLAN_PART_NUMBER OLD_PLM_ID OLD_SAP_ID  RELEASED_STATUS  \
# 8498             PXC.552024        NaN        NaN      DEVELOPMENT
# 8576             PXC.552024        NaN        NaN       PRODUCTION
# 4338            PXC.1046985        NaN        NaN      DEVELOPMENT
# 4343            PXC.1046985        NaN        NaN       PRODUCTION
# 4937             AIK.F42020        NaN        NaN      DEVELOPMENT
# 4938             AIK.F42020        NaN        NaN              NaN
# 5706           BENE.TF02PRO        NaN        NaN      DEVELOPMENT
# 5715           BENE.TF02PRO        NaN        NaN       PRODUCTION
# 795     LNX.ANT-DB1-WRT-RPS        NaN        NaN      DEVELOPMENT
# 810     LNX.ANT-DB1-WRT-RPS        NaN        NaN       PRODUCTION
# 7250          SE.XB5AW74B2N        NaN        NaN      DEVELOPMENT
# 7264          SE.XB5AW74B2N        NaN        NaN       PRODUCTION
# 4263  CUI.PYBE30-Q24-S5-DIN        NaN        NaN      DEVELOPMENT
# 4106  CUI.PYBE30-Q24-S5-DIN        NaN        NaN       PRODUCTION
# 8472            PXC.0201139        NaN        NaN      DEVELOPMENT
# 7935            PXC.0201139        NaN        NaN       PRODUCTION
#
#           RELEASED_DATE    PART_CATEGORY PART_ID_CLEANED
# 8498  22-NOV-2022 11:56  ELECTRICAL PART           14948
# 8576  26-SEP-2023 12:02  ELECTRICAL PART           14948
# 4338  22-NOV-2022 11:56  ELECTRICAL PART           15244
# 4343  27-SEP-2023 17:43  ELECTRICAL PART           15244
# 4937  22-NOV-2022 11:56  ELECTRICAL PART           17190
# 4938                NaN  ELECTRICAL PART           17190
# 5706  22-NOV-2022 11:56  ELECTRICAL PART           17437
# 5715  26-SEP-2023 12:02  ELECTRICAL PART           17437
# 795   22-NOV-2022 11:56  ELECTRICAL PART           18274
# 810   26-SEP-2023 12:02  ELECTRICAL PART           18274
# 7250  22-NOV-2022 11:56  ELECTRICAL PART           18749
# 7264  26-SEP-2023 12:02  ELECTRICAL PART           18749
# 4263  22-NOV-2022 11:56  ELECTRICAL PART           24552
# 4106  21-AUG-2023 13:30  ELECTRICAL PART           24552
# 8472  22-NOV-2022 11:56  ELECTRICAL PART           25674
# 7935  26-SEP-2023 12:02  ELECTRICAL PART           25674
#
# [16 rows x 22 columns]

# %%
def keep_latest_revision(group):
    return group.loc[group['PART_REVISION'].idxmax()]

# %%
electrical_cleaned_filtered = electrical_parts_cleaned.groupby('PART_ID_CLEANED').apply(keep_latest_revision).reset_index(drop=True)
electrical_cleaned_filtered
# Out:
# /var/folders/4c/99wh1f85111309s8ydsfjmlr0000gn/T/ipykernel_36825/339672267.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   electrical_cleaned_filtered = electrical_parts_cleaned.groupby('PART_ID_CLEANED').apply(keep_latest_revision).reset_index(drop=True)
#       PART_ID                                          PART_NAME  \
# 0       10071                                              10071
# 1       14730                                              MOTOR
# 2       14857             CABLE,M8 RIGHT ANGLED TO FREE LEADS,2M
# 3       14858                                          CONNECTOR
# 4       14859                   AIL ADAPTER FOR M3 SCREWS,,BLACK
# ...       ...                                                ...
# 9346    65209  PRE FAB CABLE-3M, WIRE HARNESS, ECONOSEAL, FRE...
# 9347    65210                                   CONNECTOR-  RJ45
# 9348    65220                                LUG-CU, TUBE, 10MM2
# 9349    65221   COMM MOD-WIFI,CLIENT, TRX A/B,  PCI EXPRESS ,20M
# 9350    65268  IPC-DIN RAIL MOUNT, 256GB, 16GB, 8-CORE ARM CO...
#
#                                        PART_DESCRIPTION  \
# 0                                                   NaN
# 1     100W, 24VDC BLDC MOTOR, 90MM FRAME, 2500RPM,6A...
# 2     SENSOR/ACTUATOR CABLE, 3-POSITION, PVC, YELLOW...
# 3     CONNECTOR, UNIVERSAL, 5-POSITION, UNSHIELDED, ...
# 4                WIDTH10 MM, HEIGHT19 MM, LENGTH42.6 MM
# ...                                                 ...
# 9346  PRE FABRICATED AUTOMOTIVE CONNECTORS WITH FLYI...
# 9347                           RJ45 90 DEGREE CONNECTOR
# 9348  CABLE LUG; SUITABLE CRIMPING INSERT: B7; FOR C...
# 9349  WIFI5 11AC 2TX2R + BT (V5.0 LE) COMBO MODULE W...
# 9350    IPC, ZED BOX ORIN<TRADEMARK> NX 16GB WITH GMSL2
#
#                           PART_OWNER  PART_REVISION      REVISION_DATE  \
# 0     HIMANSHU MEHTA (HIMANSHUMEHTA)              0  16-APR-2024 15:45
# 1       KUMARI MONIKA (KUMARIMONIKA)              0  13-OCT-2022 20:20
# 2       KUMARI MONIKA (KUMARIMONIKA)              0  18-OCT-2022 11:35
# 3       KUMARI MONIKA (KUMARIMONIKA)              0  18-OCT-2022 11:35
# 4       KUMARI MONIKA (KUMARIMONIKA)              0  18-OCT-2022 11:35
# ...                              ...            ...                ...
# 9346    KUMARI MONIKA (KUMARIMONIKA)              0  25-SEP-2024 17:40
# 9347    KUMARI MONIKA (KUMARIMONIKA)              0  25-SEP-2024 17:40
# 9348    KUMARI MONIKA (KUMARIMONIKA)              0  25-SEP-2024 17:54
# 9349    KUMARI MONIKA (KUMARIMONIKA)              0  25-SEP-2024 17:56
# 9350    KUMARI MONIKA (KUMARIMONIKA)              0  26-SEP-2024 12:12
#
#       PRODUCT_GROUP  PRODUCT_SUBGROUP  WIDTH_(MM)  HEIGHT_(MM)  ...  \
# 0               NaN               NaN         NaN          NaN  ...
# 1               9.0               1.0         0.0          0.0  ...
# 2              29.0             184.0         0.0          0.0  ...
# 3               4.0             215.0         0.0          0.0  ...
# 4              17.0               1.0         0.0          0.0  ...
# ...             ...               ...         ...          ...  ...
# 9346           29.0               1.0         0.0          0.0  ...
# 9347           17.0               1.0         0.0          0.0  ...
# 9348           17.0               1.0        10.0         29.0  ...
# 9349            8.0               1.0        26.8         30.0  ...
# 9350            1.0               1.0        92.0         71.0  ...
#
#       WEIGHT_(KG)  MANUFACTURER  MANUFACTURER_PART_NUMBER  \
# 0             NaN           NaN                       NaN
# 1             0.0      ORIENTAL             BLHM5100K-GFS
# 2             0.0     PHEONIX.C                   1406321
# 3             0.0     PHEONIX.C                   1424689
# 4             0.0     PHEONIX.C                   1200993
# ...           ...           ...                       ...
# 9346          0.0     MOTHERSON                  AT0699AA
# 9347          0.0     PHOENIX.C                   1421128
# 9348          0.0          LAPP                  61796650
# 9349          0.0          ENLI                   Q6174AH
# 9350          0.7    STEREOLABS                ZBX-320000
#
#                   EPLAN_PART_NUMBER OLD_PLM_ID OLD_SAP_ID  RELEASED_STATUS  \
# 0                               NaN        NaN        NaN              NaN
# 1                 ORM.BLHM5100K-GFS        NaN        NaN       PRODUCTION
# 2                       PXC.1406321        NaN        NaN              NaN
# 3                       PXC.1424689        NaN        NaN       PRODUCTION
# 4                       PXC.1200993        NaN        NaN              NaN
# ...                             ...        ...        ...              ...
# 9346                  MSSL.AT0699AA        NaN        NaN       PRODUCTION
# 9347  PXC.CUC-IND - C1ZNI - T/R4IP8        NaN        NaN       PRODUCTION
# 9348                  LAPP.61796650        NaN        NaN       PRODUCTION
# 9349                    ENL-Q6174AH        NaN        NaN              NaN
# 9350                STER.ZBX-320000        NaN        NaN              NaN
#
#           RELEASED_DATE    PART_CATEGORY PART_ID_CLEANED
# 0                   NaN  ELECTRICAL PART           10071
# 1     18-JAN-2023 20:06  ELECTRICAL PART           14730
# 2                   NaN  ELECTRICAL PART           14857
# 3     13-JUL-2024 21:11  ELECTRICAL PART           14858
# 4                   NaN  ELECTRICAL PART           14859
# ...                 ...              ...             ...
# 9346  26-SEP-2024 10:15  ELECTRICAL PART           65209
# 9347  26-SEP-2024 10:15  ELECTRICAL PART           65210
# 9348  26-SEP-2024 10:15  ELECTRICAL PART           65220
# 9349                NaN  ELECTRICAL PART           65221
# 9350                NaN  ELECTRICAL PART           65268
#
# [9351 rows x 22 columns]

# %%
electrical_cleaned_filtered['PART_ID'].nunique()
# Out:
# 9351

# %% [markdown]
# ### Merge the 2 cleaned datasets on Item Code & Part Id

# %%
merged_data_item_code = pd.merge(non_nan_filtered, electrical_cleaned_filtered, how="inner", left_on="ITEM_CODE_CLEANED", right_on="PART_ID_CLEANED")

# %%
merged_data_item_code.shape
# Out:
# (9796, 82)

# %%
# verifying that no repetition is there
merged_data_item_code[merged_data_item_code['PO_NUM'] == 60186]
# Out:
#         # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS  PO_NUM BASE_TYPE  \
# 948  3874       I        N    INR      1.0         C   60186        -1
#
#      BASE_NUMBER  BASE_LINE  ... WEIGHT_(KG) MANUFACTURER  \
# 948          NaN        NaN  ...         NaN       ICOTEK
#
#     MANUFACTURER_PART_NUMBER EPLAN_PART_NUMBER OLD_PLM_ID OLD_SAP_ID  \
# 948                    50741         ICO.50741        NaN        NaN
#
#     RELEASED_STATUS      RELEASED_DATE    PART_CATEGORY PART_ID_CLEANED
# 948      PRODUCTION  17-JUL-2023 16:17  ELECTRICAL PART           18165
#
# [1 rows x 82 columns]

# %%
important_columns = ['PO_NUM', 'DOCCUR', 'DOCRATE', 'SUPPLIER_CODE', 'SUPPLIER_NAME', 'DOC_DATE', 'DELIVERY_DATE', 'PO_VALUE', 'LOCATION', 'ITEM_CODE_CLEANED', 'ITEM_NAME', 'ITEM_DETAILS', 'UOM', 'ORDERED_QUANTITY', 'PRICE', 'ITEM_VALUE', 'TAX_AMOUNT(LC)', 'LINETOTAL_WITH_TAX_(LC)', 'PART_ID_CLEANED', 'PART_NAME', 'PART_DESCRIPTION', 'WIDTH_(MM)', 'HEIGHT_(MM)', 'DEPTH_(MM)', 'MOUNTING_CLEARANCES_(MM)', 'WEIGHT_(KG)']
filtered_data_final = merged_data_item_code[important_columns]
filtered_data_final
# Out:
#          PO_NUM DOCCUR  DOCRATE SUPPLIER_CODE  \
# 0         53586    INR   1.0000      VD001614
# 1         53985    INR   1.0000      VD000561
# 2         53985    INR   1.0000      VD000561
# 3         53985    INR   1.0000      VD000561
# 4         53985    INR   1.0000      VD000561
# ...         ...    ...      ...           ...
# 9791  242530635    JPY   0.5358      VF003119
# 9792  242530635    JPY   0.5358      VF003119
# 9793  242530635    JPY   0.5358      VF003119
# 9794  242530635    JPY   0.5358      VF003119
# 9795  242530642    INR   1.0000      VD003186
#
#                                   SUPPLIER_NAME   DOC_DATE DELIVERY_DATE  \
# 0         ITG SOFTWARE ENGINEERING (I) PVT. LTD 2021-10-01    2022-11-30
# 1     PEPPERL+FUCHS FACTORY AUTOMATION PVT. LTD 2021-10-19    2022-03-30
# 2     PEPPERL+FUCHS FACTORY AUTOMATION PVT. LTD 2021-10-19    2022-03-30
# 3     PEPPERL+FUCHS FACTORY AUTOMATION PVT. LTD 2021-10-19    2022-03-30
# 4     PEPPERL+FUCHS FACTORY AUTOMATION PVT. LTD 2021-10-19    2022-03-30
# ...                                         ...        ...           ...
# 9791                       ITOH DENKI CO., LTD. 2024-05-14    2024-06-25
# 9792                       ITOH DENKI CO., LTD. 2024-05-14    2024-06-25
# 9793                       ITOH DENKI CO., LTD. 2024-05-14    2024-06-25
# 9794                       ITOH DENKI CO., LTD. 2024-05-14    2024-06-25
# 9795                          YORKS ENTERPRISES 2024-05-14    2024-05-16
#
#           PO_VALUE        LOCATION ITEM_CODE_CLEANED  ... TAX_AMOUNT(LC)  \
# 0     2.764740e+07             SEA             17340  ...      3807000.0
# 1     5.073832e+06  JAGATSINGHAPUR             17360  ...         3013.2
# 2     5.073832e+06  JAGATSINGHAPUR             17365  ...        80352.0
# 3     5.073832e+06  JAGATSINGHAPUR             17376  ...        90720.0
# 4     5.073832e+06  JAGATSINGHAPUR             17378  ...        14774.4
# ...            ...             ...               ...  ...            ...
# 9791  3.135394e+05             USA             50340  ...            0.0
# 9792  3.135394e+05             USA             55993  ...            0.0
# 9793  3.135394e+05             USA             55994  ...            0.0
# 9794  3.135394e+05             USA             56001  ...            0.0
# 9795  1.180000e+03       KARNATAKA             29706  ...          180.0
#
#      LINETOTAL_WITH_TAX_(LC) PART_ID_CLEANED  \
# 0               2.495700e+07           17340
# 1               1.975320e+04           17360
# 2               5.267520e+05           17365
# 3               5.947200e+05           17376
# 4               9.685440e+04           17378
# ...                      ...             ...
# 9791            2.829024e+03           50340
# 9792            1.420406e+05           55993
# 9793            6.886102e+04           55994
# 9794            1.093032e+03           56001
# 9795            1.180000e+03           29706
#
#                                         PART_NAME  \
# 0                           SINGLE BOARD COMPUTER
# 1     FEMALE CONNECTOR M12 STRAIGHT A-CODED 8-PIN
# 2         CAMERA BASEDD LINEAR POSITIONING SENSOR
# 3                                 DISTANCE SENSOR
# 4                FEMALE CORDSET, FIELD ATTACHABLE
# ...                                           ...
# 9791   CONNECTOR-10P,FEMALE,6A,0.5SQMM,LIGHT GREY
# 9792                            CONTROLLER-24V DC
# 9793                            CONTROLLER-24V DC
# 9794    CONNECTOR-3P,FEMALE,10A,1.5 MM2,LICHTGRAU
# 9795                                      GROMMET
#
#                                        PART_DESCRIPTION  WIDTH_(MM)  \
# 0     SINGLE BOARD COMPUTERS UP SQUARED BOARD WITH C...         0.0
# 1     FEMALE CONNECTOR, FIELD-ATTACHABLE V19-G-ABG-P...         NaN
# 2                                                   NaN         NaN
# 3     OPERATING VOLTAGE UB 10 ... 30 V DC / WHEN OPE...         NaN
# 4     OPERATING VOLTAGE UB MAX. 30 V DC OPERATING CU...         NaN
# ...                                                 ...         ...
# 9791  CONDUCTOR FEMALE CONNECTOR; 0.5 MM<POW2>; PIN ...         0.0
# 9792  CONTROLLER CARD,24V DC,IP20,10.8 MS MOTOR STAR...        65.0
# 9793  CONTROLLER CARD,24V DC,IP20,43.2 MS MOTOR STAR...        84.3
# 9794  FEMALE PLUG PIN SPACING 3.5 MM,0.08 TO 1.5 MM2...        12.7
# 9795  GROMMET - ID 24 MM, GROOVE DIA.- 36 MM, GROOVE...         0.0
#
#       HEIGHT_(MM)  DEPTH_(MM) MOUNTING_CLEARANCES_(MM) WEIGHT_(KG)
# 0             0.0         0.0                      NaN       0.000
# 1             NaN         NaN                      NaN         NaN
# 2             NaN         NaN                      NaN         NaN
# 3             NaN         NaN                      NaN         NaN
# 4             NaN         NaN                      NaN         NaN
# ...           ...         ...                      ...         ...
# 9791          0.0         0.0                      NaN       0.005
# 9792        233.0         0.0                      NaN       0.000
# 9793        160.0        30.5                      NaN       0.000
# 9794         13.4        18.6                      NaN       2.458
# 9795          0.0         0.0                      NaN       0.000
#
# [9796 rows x 26 columns]

# %%
filtered_data_final.to_csv('filtered_data_final.csv')

# %%
filtered_data_final[['SUPPLIER_CODE', 'SUPPLIER_NAME']].nunique()
# Out:
# SUPPLIER_CODE    261
# SUPPLIER_NAME    260
# dtype: int64

# %%
null_suppliers = filtered_data_final[filtered_data_final['SUPPLIER_NAME'].isnull()]
null_suppliers
# Out:
# Empty DataFrame
# Columns: [PO_NUM, DOCCUR, DOCRATE, SUPPLIER_CODE, SUPPLIER_NAME, DOC_DATE, DELIVERY_DATE, PO_VALUE, LOCATION, ITEM_CODE_CLEANED, ITEM_NAME, ITEM_DETAILS, UOM, ORDERED_QUANTITY, PRICE, ITEM_VALUE, TAX_AMOUNT(LC), LINETOTAL_WITH_TAX_(LC), PART_ID_CLEANED, PART_NAME, PART_DESCRIPTION, WIDTH_(MM), HEIGHT_(MM), DEPTH_(MM), MOUNTING_CLEARANCES_(MM), WEIGHT_(KG)]
# Index: []
#
# [0 rows x 26 columns]

# %%
# duplicate_names = filtered_data_final[filtered_data_final.duplicated('SUPPLIER_NAME', keep=False)]
find_repeating_supplier_names(filtered_data_final)
# Out:
# SUPPLIER_NAME
# SEW EURODRIVE INDIA P LTD    [VCD000130, VD003949]
# TOSHIBA INDIA PVT LTD        [VD000223, VLC002025]
# Name: SUPPLIER_CODE, dtype: object

# %% [markdown]
# ### Merge the 2 datasets on Item Name & Part Name

# %%
merged_data_item_name = pd.merge(df_cleaned_nan, electrical_cleaned_filtered, how="inner", left_on="ITEM_NAME", right_on="PART_NAME")
merged_data_item_name
# Out:
#         # DOCTYPE CANCELED DOCCUR  DOCRATE DOCSTATUS     PO_NUM BASE_TYPE  \
# 0   30747       S        N    INR      1.0         C  232432530        PR
# 1   30747       S        N    INR      1.0         C  232432530        PR
# 2   30747       S        N    INR      1.0         C  232432530        PR
# 3   30747       S        N    INR      1.0         C  232432530        PR
# 4   30747       S        N    INR      1.0         C  232432530        PR
# 5   30747       S        N    INR      1.0         C  232432530        PR
# 6   30747       S        N    INR      1.0         C  232432530        PR
# 7   30747       S        N    INR      1.0         C  232432530        PR
# 8   30747       S        N    INR      1.0         C  232432530        PR
# 9   30747       S        N    INR      1.0         C  232432530        PR
# 10  30747       S        N    INR      1.0         C  232432530        PR
# 11  30747       S        N    INR      1.0         C  232432530        PR
# 12  30747       S        N    INR      1.0         C  232432530        PR
# 13  30747       S        N    INR      1.0         C  232432530        PR
# 14  30747       S        N    INR      1.0         C  232432530        PR
# 15  30747       S        N    INR      1.0         C  232432530        PR
# 16   2849       S        N    INR      1.0         C      59430        -1
#
#     BASE_NUMBER  BASE_LINE  ... WEIGHT_(KG)   MANUFACTURER  \
# 0   232402827.0        4.0  ...         NaN           SONI
# 1   232402827.0        4.0  ...         NaN           SONI
# 2   232402827.0        4.0  ...         NaN           SONI
# 3   232402827.0        4.0  ...         NaN           SONI
# 4   232402827.0        4.0  ...         NaN           SONI
# 5   232402827.0        4.0  ...         NaN           SONI
# 6   232402827.0        4.0  ...         NaN           SONI
# 7   232402827.0        4.0  ...         NaN           SONI
# 8   232402827.0        4.0  ...         NaN           SONI
# 9   232402827.0        4.0  ...         NaN           SONI
# 10  232402827.0        4.0  ...         NaN  SAHARA LABELS
# 11  232402827.0        4.0  ...         NaN  SAHARA LABELS
# 12  232402827.0        4.0  ...         NaN  SAHARA LABELS
# 13  232402827.0        4.0  ...         NaN           SONI
# 14  232402827.0        4.0  ...         NaN           SONI
# 15  232402827.0        4.0  ...         NaN           SONI
# 16          NaN        NaN  ...         NaN     TECHVISION
#
#    MANUFACTURER_PART_NUMBER    EPLAN_PART_NUMBER OLD_PLM_ID OLD_SAP_ID  \
# 0                PWS-D/S-CA      SONI.PWS-D/S-CA        NaN        NaN
# 1            PWS-440/230-CA  SONI.PWS-440/230-CA        NaN        NaN
# 2                PWS-230-CA      SONI.PWS-230-CA        NaN        NaN
# 3                PWS-440-CA      SONI.PWS-440-CA        NaN        NaN
# 4                 PWS-AS-CA       SONI.PWS-AS-CA        NaN        NaN
# 5            PWS-480/110-CA  SONI.PWS-480/110-CA        NaN        NaN
# 6                PWS-480-CA      SONI.PWS-480-CA        NaN        NaN
# 7                PWS-110-CA      SONI.PWS-110-CA        NaN        NaN
# 8            PWS-400/230-CA  SONI.PWS-400/230-CA        NaN        NaN
# 9                PWS-400-CA      SONI.PWS-400-CA        NaN        NaN
# 10               PWS-D/S-CA    SAHARA.PWS-D/S-CA        NaN        NaN
# 11                PWS-AS-CA     SAHARA.PWS-AS-CA        NaN        NaN
# 12               PWS-230-CA    SAHARA.PWS-230-CA        NaN        NaN
# 13           PWS-380/220-CA  SONI.PWS-380/220-CA        NaN        NaN
# 14               PWS-380-CA      SONI.PWS-380-CA        NaN        NaN
# 15               PWS-220-CA      SONI.PWS-220-CA        NaN        NaN
# 16                CCTVINSTA         TV.CCTVINSTA        NaN        NaN
#
#    RELEASED_STATUS      RELEASED_DATE    PART_CATEGORY PART_ID_CLEANED
# 0       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31151
# 1       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31152
# 2       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31153
# 3       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31154
# 4       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31155
# 5       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31158
# 6       PRODUCTION  13-FEB-2023 12:31  ELECTRICAL PART           31159
# 7       PRODUCTION  16-FEB-2023 13:38  ELECTRICAL PART            3116
# 8       PRODUCTION  17-APR-2023 10:50  ELECTRICAL PART            3392
# 9       PRODUCTION  17-APR-2023 10:50  ELECTRICAL PART           33921
# 10      PRODUCTION  09-MAY-2023 17:53  ELECTRICAL PART           34792
# 11      PRODUCTION  09-MAY-2023 17:53  ELECTRICAL PART           34793
# 12      PRODUCTION  09-MAY-2023 17:53  ELECTRICAL PART           34794
# 13      PRODUCTION  03-JUN-2023 17:38  ELECTRICAL PART           36035
# 14      PRODUCTION  03-JUN-2023 17:38  ELECTRICAL PART           36036
# 15      PRODUCTION  02-JUN-2023 14:08  ELECTRICAL PART           36057
# 16      PRODUCTION  01-DEC-2022 12:18  ELECTRICAL PART           26241
#
# [17 rows x 81 columns]

# %% [markdown]
# #### Checking if the NaN item code unique PO Nums match the merged data PO Nums

# %%
nan_item_code_po_nums = df_cleaned_nan['PO_NUM'].unique()
len(nan_item_code_po_nums)
# Out:
# 2462

# %%
merged_data_po_nums = merged_data_item_code['PO_NUM'].unique()
len(merged_data_po_nums)
# Out:
# 3825

# %%
print(len(np.union1d(nan_item_code_po_nums, merged_data_po_nums)))
print(len(np.intersect1d(nan_item_code_po_nums, merged_data_po_nums)))
# Out:
# 6287
# 0
